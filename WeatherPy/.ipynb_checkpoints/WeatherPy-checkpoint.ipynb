# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import seaborn as sns

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#Use ! in front of the code if you are running terminal commands
#!pip install seaborn
#!pip freeze 
#!pip install citipy

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %%
#Just to check the cities in the list
print(cities)
# Out:
# ['bluff', 'kalmunai', 'atuona', 'mataura', 'abha', 'georgetown', 'lorengau', 'khor', 'hobart', 'arraial do cabo', 'upernavik', 'meulaboh', 'seminole', 'muravlenko', 'oranjestad', 'tsihombe', 'baglung', 'lebu', 'mrirt', 'rikitea', 'new norfolk', 'ponta delgada', 'tasiilaq', 'taoudenni', 'teguise', 'hauzenberg', 'hermanus', 'clyde river', 'istok', 'gobabis', 'illoqqortoormiut', 'chokurdakh', 'cockburn town', 'xapuri', 'busselton', 'camapua', 'bambous virieux', 'ndioum', 'dingle', 'vaini', 'talnakh', 'polovinnoye', 'kodiak', 'richards bay', 'qaqortoq', 'kenai', 'souillac', 'kaeo', 'ancud', 'fort nelson', 'balykshi', 'alekseyevsk', 'bredasdorp', 'mount gambier', 'saint-philippe', 'codrington', 'nizhneyansk', 'sumbawa', 'vallenar', 'khatanga', 'kavaratti', 'barrow', 'broken hill', 'diego de almagro', 'chapleau', 'punta arenas', 'daru', 'coahuayana', 'alta floresta', 'george', 'saint george', 'beringovskiy', 'dunedin', 'albany', 'butaritari', 'oistins', 'atambua', 'ushuaia', 'borlange', 'taolanaro', 'vaitupu', 'westport', 'adrar', 'japura', 'sao gabriel da cachoeira', 'mishan', 'thompson', 'honningsvag', 'norsup', 'anqing', 'ayagoz', 'sampit', 'santarem', 'belushya guba', 'ponta do sol', 'sedelnikovo', 'itarema', 'jackson', 'laguna', 'iquique', 'yangambi', 'necochea', 'emerald', 'broome', 'zaysan', 'fukue', 'fare', 'klaksvik', 'karaul', 'pizhanka', 'yellowknife', 'morehead', 'mar del plata', 'lira', 'airai', 'dangtu', 'cabo san lucas', 'norman wells', 'flin flon', 'monroe', 'avarua', 'touros', 'zhangye', 'bandarbeyla', 'hendersonville', 'tumannyy', 'kapaa', 'port alfred', 'hilo', 'nikolskoye', 'warqla', 'bethel', 'pisco', 'mahon', 'svetlogorsk', 'kazalinsk', 'villa maria', 'maniitsoq', 'goch', 'cidreira', 'tahoua', 'rocha', 'akyab', 'qaanaaq', 'methoni', 'bela', 'bogorodsk', 'ballina', 'fortuna', 'jamestown', 'yandoon', 'humaita', 'buala', 'ankang', 'kikwit', 'aykhal', 'samarai', 'fenoarivo', 'puerto ayora', 'kahului', 'saskylakh', 'pontes e lacerda', 'maralal', 'kampot', 'dikson', 'hofn', 'geraldton', 'bjerkvik', 'aleksandro-nevskiy', 'zhigansk', 'biltine', 'san ignacio', 'bengkulu', 'tulun', 'hithadhoo', 'mouzakion', 'itoman', 'bowen', 'tilichiki', 'abu kamal', 'pevek', 'ambilobe', 'lovozero', 'ocampo', 'esperance', 'takoradi', 'mahebourg', 'boueni', 'carnot', 'pangnirtung', 'tuktoyaktuk', 'ereymentau', 'port-de-paix', 'kendari', 'shakawe', 'barra do garcas', 'manzil salim', 'kaitangata', 'sao joao da barra', 'bani', 'galle', 'yilan', 'nanortalik', 'hualmay', 'saint-joseph', 'jinchengjiang', 'teknaf', 'bow island', 'nguru', 'calvinia', 'lompoc', 'maceio', 'shubarkuduk', 'cape town', 'husavik', 'atar', 'boyle', 'chardara', 'carnarvon', 'kambove', 'vrangel', 'haradok', 'torbay', 'neiafu', 'pochutla', 'karratha', 'kruisfontein', 'piracanjuba', 'guerrero negro', 'mandalgovi', 'fuling', 'krasnyy chikoy', 'parrita', 'tiznit', 'bullhead city', 'amderma', 'tommot', 'troitskiy', 'raga', 'deputatskiy', 'malyn', 'komsomolskiy', 'binzhou', 'narsaq', 'kautokeino', 'yulara', 'avera', 'bubaque', 'thinadhoo', 'ust-nera', 'altamont', 'hami', 'iqaluit', 'hovd', 'cayenne', 'victoria', 'hasaki', 'cap malheureux', 'constitucion', 'ribeira grande', 'walvis bay', 'bathsheba', 'castro', 'valparaiso', 'san quintin', 'port pirie', 'kiunga', 'jiangyou', 'kalino', 'sabya', 'saldanha', 'kotma', 'bobcaygeon', 'la grande', 'ondo', 'akdepe', 'jalu', 'sur', 'batagay', 'maragogi', 'meyungs', 'meiganga', 'saint anthony', 'pontalina', 'tuatapere', 'gazli', 'bonney lake', 'vila franca do campo', 'nuuk', 'beloha', 'korampallam', 'salgar', 'port elizabeth', 'tocopilla', 'miyazu', 'isangel', 'skibbereen', 'samalaeulu', 'prieska', 'vao', 'tiksi', 'kamenskoye', 'felidhoo', 'somanda', 'prince rupert', 'sepatan', 'ushtobe', 'brae', 'provideniya', 'grand gaube', 'labuhan', 'seoul', 'port-cartier', 'leshukonskoye', 'sentyabrskiy', 'sehwan', 'rochegda', 'ipora', 'nabire', 'saint-augustin', 'krasnokholmskiy', 'belmonte', 'samana', 'mahibadhoo', 'vizianagaram', 'yanan', 'bone',  ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).
#
# > **HINT:** The OpenWeatherMap API only allows 60 calls per minute under their free plan. Try using `time.sleep(60)` after each set of 50 cities to avoid API errors due to large calls.

# %%
#Openweather API Calls
url = "http://api.openweathermap.org/data/2.5/weather?"
#The open weather API requires units as a parameter
unit_parameter = "imperial"

# Build partial query URL and use sample city to test
query_url_test = f"{url}appid={weather_api_key}&units={unit_parameter}&q=Knoxville"
#Commented out the display (query_url) after testing because display revealed the keys in the url
#display (query_url_test)

# %%
#Partial QUery from Test Section Above
query_url= f"{url}appid={weather_api_key}&units={unit_parameter}&q="
#Commented out the display (query_url) after testing because display revealed the keys in the url
#display (query_url)

# %%
#Creating an empty dataframe
df = pd.DataFrame(columns=['country', 'city', 'lat', 'lon', 'date', 'cloudiness', 'humidity', 'max_temp', 'wind_speed'])

display(df)
# Out:
# Empty DataFrame
# Columns: [country, city, lat, lon, date, cloudiness, humidity, max_temp, wind_speed]
# Index: []

# %%
#Building the query
#I knew the query would would generate the correct results after the testing above using Knoxville.
query_url= f"{url}appid={weather_api_key}&units={unit_parameter}&q="

# %%
count = 1

for city in cities:
    if count % 50 == 0:
        time.sleep(60)
    try:
        print(f'Retrieving data for city {city}')
        #Get values for current city
        city_info = requests.get(query_url + city).json()
        country = city_info['sys']['country']
        date = city_info['dt']
        lat = city_info['coord']['lat']
        lon = city_info['coord']['lon']
        clouds = city_info['clouds']['all']
        humidity = city_info['main']['humidity']
        max_temp = city_info['main']['temp_max']
        wind_speed = city_info['wind']['speed']
        
        #Create a dictionary
        current_city_dict = {
            'country': country,
            'city': city,
            'lat': lat,
            'lon': lon,
            'date': date,
            'cloudiness': clouds,
            'humidity': humidity,
            'max_temp': max_temp,
            'wind_speed': wind_speed
        }
        
        #Convert dictionary to dataframe for current city
        current_city = pd.DataFrame([current_city_dict])
        
        #Concatenate main df with current city dataframe
        df = pd.concat([df, current_city]).reset_index(drop=True)
        
    except:
        print(f'Data for city {city} is not available')
    
    count+=1
# Out:
# Retrieving data for city bluff
# Retrieving data for city kalmunai
# Retrieving data for city atuona
# Retrieving data for city mataura
# Retrieving data for city abha
# Retrieving data for city georgetown
# Retrieving data for city lorengau
# Retrieving data for city khor
# Retrieving data for city hobart
# Retrieving data for city arraial do cabo
# Retrieving data for city upernavik
# Retrieving data for city meulaboh
# Retrieving data for city seminole
# Retrieving data for city muravlenko
# Retrieving data for city oranjestad
# Retrieving data for city tsihombe
# Data for city tsihombe is not available
# Retrieving data for city baglung
# Retrieving data for city lebu
# Retrieving data for city mrirt
# Data for city mrirt is not available
# Retrieving data for city rikitea
# Retrieving data for city new norfolk
# Retrieving data for city ponta delgada
# Retrieving data for city tasiilaq
# Retrieving data for city taoudenni
# Retrieving data for city teguise
# Retrieving data for city hauzenberg
# Retrieving data for city hermanus
# Retrieving data for city clyde river
# Retrieving data for city istok
# Retrieving data for city gobabis
# Retrieving data for city illoqqortoormiut
# Data for city illoqqortoormiut is not available
# Retrieving data for city chokurdakh
# Retrieving data for city cockburn town
# Retrieving data for city xapuri
# Retrieving data for city busselton
# Retrieving data for city camapua
# Retrieving data for city bambous virieux
# Retrieving data for city ndioum
# Retrieving data for city dingle
# Retrieving data for city vaini
# Retrieving data for city talnakh
# Retrieving data for city polovinnoye
# Retrieving data for city kodiak
# Retrieving data for city richards bay
# Retrieving data for city qaqortoq
# Retrieving data for city kenai
# Retrieving data for city souillac
# Retrieving data for city kaeo
# Retrieving data for city ancud
# Retrieving data for city fort nelson
# Retrieving data for city balykshi
# Retrieving data for city alekseyevsk
# Retrieving data for city bredasdorp
# Retrieving data for city mount gambier
# Retrieving data for city saint-philippe
# Retrieving data for city codrington
# Retrieving data for city nizhneyansk
# Data for city nizhneyansk is not available
# Retrieving data for city sumbawa
# Data for city sumbawa is not available
# Retrieving data for city vallenar
# Retrieving data for city khatanga
# Retrieving data for city kavaratti
# Retrieving data for city barrow
# Retrieving data for city broken hill
# Retrieving data for city diego de almagro
# Retrieving data for city chapleau
# Retrieving data for city punta arenas
# Retrieving data for city daru
# Retrieving data for city coahuayana
# Retrieving data for city alta floresta
# Retrieving data for city george
# Retrieving data for city saint george
# Retrieving data for city beringovskiy
# Retrieving data for city dunedin
# Retrieving data for city albany
# Retrieving data for city butaritari
# Retrieving data for city oistins
# Retrieving data for city atambua
# Retrieving data for city ushuaia
# Retrieving data for city borlange
# Data for city borlange is not available
# Retrieving data for city taolanaro
# Data for city taolanaro is not available
# Retrieving data for city vaitupu
# Data for city vaitupu is not available
# Retrieving data for city westport
# Retrieving data for city adrar
# Retrieving data for city japura
# Retrieving data for city sao gabriel da cachoeira
# Retrieving data for city mishan
# Retrieving data for city thompson
# Retrieving data for city honningsvag
# Retrieving data for city norsup
# Retrieving data for city anqing
# Retrieving data for city ayagoz
# Retrieving data for city sampit
# Retrieving data for city santarem
# Retrieving data for city belushya guba
# Data for city belushya guba is not available
# Retrieving data for city ponta do sol
# Retrieving data for city sedelnikovo
# Data for city sedelnikovo is not available
# Retrieving data for city itarema
# Retrieving data for city jackson
# Retrieving data for city laguna
# Retrieving data for city iquique
# Retrieving data for city yangambi
# Retrieving data for city necochea
# Retrieving data for city emerald
# Retrieving data for city broome
# Retrieving data for city zaysan
# Retrieving data for city fukue
# Retrieving data for city fare
# Retrieving data for city klaksvik
# Retrieving data for city karaul
# Data for city karaul is not available
# Retrieving data for city pizhanka
# Retrieving data for city yellowknife
# Retrieving data for city morehead
# Retrieving data for city mar del plata
# Retrieving data for city lira
# Retrieving data for city airai
# Retrieving data for city dangtu
# Retrieving data for city cabo san lucas
# Retrieving data for city norman wells
# Retrieving data for city flin flon
# Retrieving data for city monroe
# Retrieving data for city avarua
# Retrieving data for city touros
# Retrieving data for city zhangye
# Retrieving data for city bandarbeyla
# Retrieving data for city hendersonville
# Retrieving data for city tumannyy
# Data for city tumannyy is not available
# Retrieving data for city kapaa
# Retrieving data for city port alfred
# Retrieving data for city hilo
# Retrieving data for city nikolskoye
# Retrieving data for city warqla
# Data for city warqla is not available
# Retrieving data for city bethel
# Retrieving data for city pisco
# Retrieving data for city mahon
# Retrieving data for city svetlogorsk
# Retrieving data for city kazalinsk
# Data for city kazalinsk is not available
# Retrieving data for city villa maria
# Retrieving data for city maniitsoq
# Retrieving data for city goch
# Retrieving data for city cidreira
# Retrieving data for city tahoua
# Retrieving data for city rocha
# Retrieving data for city akyab
# Retrieving data for city qaanaaq
# Retrieving data for city methoni
# Retrieving data for city bela
# Retrieving data for city bogorodsk
# Retrieving data for city ballina
# Retrieving data for city fortuna
# Retrieving data for city jamestown
# Retrieving data for city yandoon
# Data for city yandoon is not available
# Retrieving data for city humaita
# Retrieving data for city buala
# Retrieving data for city ankang
# Retrieving data for city kikwit
# Retrieving data for city aykhal
# Retrieving data for city samarai
# Retrieving data for city fenoarivo
# Retrieving data for city puerto ayora
# Retrieving data for city kahului
# Retrieving data for city saskylakh
# Retrieving data for city pontes e lacerda
# Retrieving data for city maralal
# Retrieving data for city kampot
# Retrieving data for city dikson
# Retrieving data for city hofn
# Retrieving data for city geraldton
# Retrieving data for city bjerkvik
# Retrieving data for city aleksandro-nevskiy
# Retrieving data for city zhigansk
# Retrieving data for city biltine
# Retrieving data for city san ignacio
# Retrieving data for city bengkulu
# Retrieving data for city tulun
# Retrieving data for city hithadhoo
# Retrieving data for city mouzakion
# Data for city mouzakion is not available
# Retrieving data for city itoman
# Retrieving data for city bowen
# Retrieving data for city tilichiki
# Retrieving data for city abu kamal
# Retrieving data for city pevek
# Retrieving data for city ambilobe
# Retrieving data for city lovozero
# Retrieving data for city ocampo
# Retrieving data for city esperance
# Retrieving data for city takoradi
# Retrieving data for city mahebourg
# Retrieving data for city boueni
# Retrieving data for city carnot
# Retrieving data for city pangnirtung
# Retrieving data for city tuktoyaktuk
# Retrieving data for city ereymentau
# Retrieving data for city port-de-paix
# Data for city port-de-paix is not available
# Retrieving data for city kendari
# Retrieving data for city shakawe
# Retrieving data for city barra do garcas
# Retrieving data for city manzil salim
# Retrieving data for city kaitangata
# Retrieving data for city sao joao da barra
# Retrieving data for city bani
# Retrieving data for city galle
# Retrieving data for city yilan
# Retrieving data for city nanortalik
# Retrieving data for city hualmay
# Retrieving data for city saint-joseph
# Retrieving data for city jinchengjiang
# Data for city jinchengjiang is not available
# Retrieving data for city teknaf
# Retrieving data for city bow island
# Retrieving data for city nguru
# Retrieving data for city calvinia
# Retrieving data for city lompoc
# Retrieving data for city maceio
# Retrieving data for city shubarkuduk
# Retrieving data for city cape town
# Retrieving data for city husavik
# Retrieving data for city atar
# Retrieving data for city boyle
# Retrieving data for city chardara
# Retrieving data for city carnarvon
# Retrieving data for city kambove
# Retrieving data for city vrangel
# Retrieving data for city haradok
# Retrieving data for city torbay
# Retrieving data for city neiafu
# Retrieving data for city pochutla
# Retrieving data for city karratha
# Retrieving data for city kruisfontein
# Retrieving data for city piracanjuba
# Retrieving data for city guerrero negro
# Retrieving data for city mandalgovi
# Retrieving data for city fuling
# Retrieving data for city krasnyy chikoy
# Retrieving data for city parrita
# Retrieving data for city tiznit
# Retrieving data for city bullhead city
# Retrieving data for city amderma
# Data for city amderma is not available
# Retrieving data for city tommot
# Retrieving data for city troitskiy
# Retrieving data for city raga
# Retrieving data for city deputatskiy
# Retrieving data for city malyn
# Retrieving data for city komsomolskiy
# Retrieving data for city binzhou
# Retrieving data for city narsaq
# Retrieving data for city kautokeino
# Retrieving data for city yulara
# Retrieving data for city avera
# Retrieving data for city bubaque
# Retrieving data for city thinadhoo
# Retrieving data for city ust-nera
# Retrieving data for city altamont
# Retrieving data for city hami
# Retrieving data for city iqaluit
# Retrieving data for city hovd
# Retrieving data for city cayenne
# Retrieving data for city victoria
# Retrieving data for city hasaki
# Retrieving data for city cap malheureux
# Retrieving data for city constitucion
# Retrieving data for city ribeira grande
# Retrieving data for city walvis bay
# Retrieving data for city bathsheba
# Retrieving data for city castro
# Retrieving data for city valparaiso
# Retrieving data for city san quintin
# Retrieving data for city port pirie
# Retrieving data for city kiunga
# Retrieving data for city jiangyou
# Retrieving data for city kalino
# Retrieving data for city sabya
# Retrieving data for city saldanha
# Retrieving data for city kotma
# Retrieving data for city bobcaygeon
# Retrieving data for city la grande
# Retrieving data for city ondo
# Retrieving data for city akdepe
# Retrieving data for city jalu
# Retrieving data for city sur
# Retrieving data for city batagay
# Retrieving data for city maragogi
# Retrieving data for city meyungs
# Data for city meyungs is not available
# Retrieving data for city meiganga
# Retrieving data for city saint anthony
# Retrieving data for city pontalina
# Retrieving data for city tuatapere
# Retrieving data for city gazli
# Retrieving data for city bonney lake
# Retrieving data for city vila franca do campo
# Retrieving data for city nuuk
# Retrieving data for city beloha
# Retrieving data for city korampallam
# Retrieving data for city salgar
# Retrieving data for city port elizabeth
# Retrieving data for city tocopilla
# Retrieving data for city miyazu
# Retrieving data for city isangel
# Retrieving data for city skibbereen
# Retrieving data for city samalaeulu
# Data for city samalaeulu is not available
# Retrieving data for city prieska
# Retrieving data for city vao
# Retrieving data for city tiksi
# Retrieving data for city kamenskoye
# Data for city kamenskoye is not available
# Retrieving data for city felidhoo
# Data for city felidhoo is not available
# Retrieving data for city somanda
# Retrieving data for city prince rupert
# Retrieving data for city sepatan
# Retrieving data for city ushtobe
# Retrieving data for city brae
# Retrieving data for city provideniya
# Retrieving data for city grand gaube
# Retrieving data for city labuhan
# Retrieving data for city seoul
# Retrieving data for city port-cartier
# Retrieving data for city leshukonskoye
# Retrieving data for city sentyabrskiy
# Data for city sentyabrskiy is not available
# Retrieving data for city sehwan
# Retrieving data for city rochegda
# Retrieving data for city ipora
# Retrieving data for city nabire
# Retrieving data for city saint-augustin
# Retrieving data for city krasnokholmskiy
# Retrieving data for city belmonte
# Retrieving data for city samana
# Retrieving data for city mahibadhoo
# Retrieving data for city vizianagaram
# Retrieving data for city yanan
# Data for city yanan is not available
# Retrieving data for city bone
# Retrieving data for city san patricio
# Retrieving data for city ostrovnoy
# Retrieving data for city luderitz
# Retrieving data for city si sa ket
# Retrieving data for city wanning
# Retrieving data for city sakakah
# Retrieving data for city rolim de moura
# Data for city rolim de moura is not available
# Retrieving data for city kawana waters
# Data for city kawana waters is not available
# Retrieving data for city lolua
# Data for city lolua is not available
# Retrieving data for city saleaula
# Data for city saleaula is not available
# Retrieving data for city santo andre
# Retrieving data for city chimbote
# Retrieving data for city mocuba
# Retrieving data for city bosaso
# Retrieving data for city saint-leu
# Retrieving data for city viedma
# Retrieving data for city chernyshevskiy
# Retrieving data for city remontnoye
# Retrieving data for city turukhansk
# Retrieving data for city narasannapeta
# Retrieving data for city waterloo
# Retrieving data for city kozhva
# Retrieving data for city cherskiy
# Retrieving data for city hambantota
# Retrieving data for city karasjok
# Retrieving data for city peoria
# Retrieving data for city visegrad
# Retrieving data for city sancti spiritus
# Retrieving data for city eldikan
# Data for city eldikan is not available
# Retrieving data for city doume
# Retrieving data for city general roca
# Retrieving data for city noumea
# Retrieving data for city port blair
# Retrieving data for city naze
# Retrieving data for city lavrentiya
# Retrieving data for city avigliano
# Retrieving data for city punta umbria
# Retrieving data for city nemuro
# Retrieving data for city east london
# Retrieving data for city narrabri
# Retrieving data for city san cristobal
# Retrieving data for city verkhoyansk
# Retrieving data for city morondava
# Retrieving data for city agogo
# Retrieving data for city nome
# Retrieving data for city pouembout
# Retrieving data for city vestmannaeyjar
# Retrieving data for city pohrebyshche
# Retrieving data for city portland
# Retrieving data for city limoux
# Retrieving data for city aasiaat
# Retrieving data for city berlevag
# Retrieving data for city rawson
# Retrieving data for city vilhena
# Retrieving data for city chicama
# Retrieving data for city borisoglebsk
# Retrieving data for city srivardhan
# Retrieving data for city lazaro cardenas
# Retrieving data for city longyearbyen
# Retrieving data for city yuci
# Retrieving data for city bilma
# Retrieving data for city attawapiskat
# Data for city attawapiskat is not available
# Retrieving data for city nzerekore
# Retrieving data for city yamada
# Retrieving data for city byron bay
# Retrieving data for city ondorhaan
# Data for city ondorhaan is not available
# Retrieving data for city general pico
# Retrieving data for city tautira
# Retrieving data for city surgut
# Retrieving data for city tokmak
# Retrieving data for city arman
# Retrieving data for city sharjah
# Retrieving data for city katunino
# Retrieving data for city dwarka
# Retrieving data for city oranjemund
# Retrieving data for city yarim
# Retrieving data for city te anau
# Retrieving data for city halalo
# Data for city halalo is not available
# Retrieving data for city egvekinot
# Retrieving data for city umm lajj
# Retrieving data for city katsuura
# Retrieving data for city palabuhanratu
# Data for city palabuhanratu is not available
# Retrieving data for city conceicao do araguaia
# Retrieving data for city hamilton
# Retrieving data for city kavieng
# Retrieving data for city barentsburg
# Data for city barentsburg is not available
# Retrieving data for city chihuahua
# Retrieving data for city andra
# Retrieving data for city quincy
# Retrieving data for city samfya
# Retrieving data for city coquimbo
# Retrieving data for city missoula
# Retrieving data for city kijang
# Retrieving data for city faanui
# Retrieving data for city guaymas
# Retrieving data for city marzuq
# Retrieving data for city mezhdurechensk
# Retrieving data for city itacare
# Retrieving data for city saryg-sep
# Retrieving data for city silver city
# Retrieving data for city kirakira
# Retrieving data for city bodden town
# Retrieving data for city buraydah
# Retrieving data for city colac
# Retrieving data for city biak
# Retrieving data for city tessalit
# Retrieving data for city kysyl-syr
# Retrieving data for city louisbourg
# Data for city louisbourg is not available
# Retrieving data for city matagami
# Retrieving data for city huarmey
# Retrieving data for city otane
# Retrieving data for city weligama
# Retrieving data for city ust-ilimsk
# Retrieving data for city mys shmidta
# Data for city mys shmidta is not available
# Retrieving data for city mayo
# Retrieving data for city kawalu
# Retrieving data for city rupert
# Retrieving data for city haines junction
# Retrieving data for city banda aceh
# Retrieving data for city olafsvik
# Retrieving data for city eyl
# Retrieving data for city bambanglipuro
# Retrieving data for city unye
# Data for city unye is not available
# Retrieving data for city maua
# Retrieving data for city barra do corda
# Retrieving data for city kochevo
# Retrieving data for city kiama
# Retrieving data for city bidar
# Retrieving data for city cedar city
# Retrieving data for city ondjiva
# Retrieving data for city copiapo
# Retrieving data for city yatou
# Retrieving data for city poronaysk
# Retrieving data for city mozarlandia
# Retrieving data for city virginia beach
# Retrieving data for city stornoway
# Retrieving data for city taganak
# Retrieving data for city jasper
# Retrieving data for city simao
# Retrieving data for city ust-maya
# Retrieving data for city solsvik
# Data for city solsvik is not available
# Retrieving data for city radishchevo
# Retrieving data for city palmer
# Retrieving data for city north bend
# Retrieving data for city bokspits
# Data for city bokspits is not available
# Retrieving data for city tikri
# Retrieving data for city nouadhibou
# Retrieving data for city severo-kurilsk
# Retrieving data for city esil
# Retrieving data for city abilene
# Retrieving data for city tabiauea
# Data for city tabiauea is not available
# Retrieving data for city kushima
# Retrieving data for city poum
# Retrieving data for city abonnema
# Retrieving data for city diu
# Retrieving data for city puerto escondido
# Retrieving data for city carlisle
# Retrieving data for city ilulissat
# Retrieving data for city ahipara
# Retrieving data for city birao
# Retrieving data for city makakilo city
# Retrieving data for city beihai
# Retrieving data for city barreirinha
# Retrieving data for city turbat
# Retrieving data for city port-gentil
# Retrieving data for city yokadouma
# Retrieving data for city tazovskiy
# Retrieving data for city alice springs
# Retrieving data for city benguela
# Retrieving data for city aklavik
# Retrieving data for city nagato
# Retrieving data for city jijiga
# Retrieving data for city silvassa
# Retrieving data for city half moon bay
# Retrieving data for city bondo
# Retrieving data for city toora-khem
# Retrieving data for city hervey bay
# Retrieving data for city el rodeo
# Retrieving data for city sandwick
# Retrieving data for city lalibela
# Retrieving data for city preobrazheniye
# Retrieving data for city baykit
# Retrieving data for city aswan
# Retrieving data for city grand river south east
# Data for city grand river south east is not available
# Retrieving data for city moose factory
# Retrieving data for city ust-kamchatsk
# Data for city ust-kamchatsk is not available
# Retrieving data for city tabas
# Retrieving data for city mabaruma
# Retrieving data for city oyon
# Retrieving data for city mnogovershinnyy
# Retrieving data for city taloda
# Retrieving data for city kaitong
# Retrieving data for city ramhormoz
# Retrieving data for city bismil
# Retrieving data for city luganville
# Retrieving data for city the valley
# Retrieving data for city sinkat
# Data for city sinkat is not available
# Retrieving data for city bhaktapur
# Retrieving data for city synya
# Retrieving data for city pacific grove
# Retrieving data for city dormidontovka
# Retrieving data for city sambava
# Retrieving data for city flinders
# Retrieving data for city narino
# Retrieving data for city san jose
# Retrieving data for city chapais
# Retrieving data for city bonavista
# Retrieving data for city karkaralinsk
# Data for city karkaralinsk is not available
# Retrieving data for city west fargo
# Retrieving data for city korla
# Retrieving data for city agadir
# Retrieving data for city sinjhoro
# Retrieving data for city dakar
# Retrieving data for city aripuana
# Retrieving data for city yeniseysk
# Retrieving data for city fez
# Retrieving data for city buchanan
# Retrieving data for city waipawa
# Retrieving data for city del rio
# Retrieving data for city yian
# Data for city yian is not available
# Retrieving data for city sao pedro do sul
# Retrieving data for city abu jubayhah
# Data for city abu jubayhah is not available
# Retrieving data for city council bluffs
# Retrieving data for city catuday
# Retrieving data for city la ronge
# Retrieving data for city bras-panon
# Retrieving data for city strezhevoy
# Retrieving data for city velez-malaga
# Retrieving data for city demba
# Retrieving data for city katobu
# Retrieving data for city quatre cocos
# Retrieving data for city sinnamary
# Retrieving data for city petersburg
# Retrieving data for city banjar
# Retrieving data for city lata
# Retrieving data for city comodoro rivadavia
# Retrieving data for city acapulco
# Retrieving data for city sistranda
# Retrieving data for city matay
# Retrieving data for city swift current
# Retrieving data for city lagoa
# Retrieving data for city vila velha
# Retrieving data for city nhulunbuy
# Retrieving data for city padang
# Retrieving data for city xiaoyi
# Retrieving data for city chandler
# Retrieving data for city sarakhs
# Retrieving data for city gigmoto
# Retrieving data for city hvolsvollur
# Retrieving data for city coihaique
# Retrieving data for city izumo
# Retrieving data for city cumberland
# Retrieving data for city nardaran
# Retrieving data for city xiongzhou
# Retrieving data for city zholymbet
# Retrieving data for city presidencia roque saenz pena
# Retrieving data for city mongomo
# Retrieving data for city sawtell
# Retrieving data for city mergui
# Data for city mergui is not available
# Retrieving data for city marsh harbour
# Retrieving data for city soe
# Retrieving data for city wewak
# Retrieving data for city parakai
# Retrieving data for city porto walter
# Retrieving data for city santiago del estero
# Retrieving data for city tura
# Retrieving data for city nioki
# Retrieving data for city nazca
# Retrieving data for city kiruna
# Retrieving data for city novovasylivka
# Retrieving data for city maarianhamina
# Retrieving data for city ketchikan
# Retrieving data for city nileshwar
# Retrieving data for city warri
# Retrieving data for city kungurtug
# Retrieving data for city umzimvubu
# Data for city umzimvubu is not available
# Retrieving data for city petropavlovsk-kamchatskiy
# Retrieving data for city namatanai
# Retrieving data for city pyaozerskiy
# Retrieving data for city chengmai
# Data for city chengmai is not available
# Retrieving data for city senador guiomard
# Retrieving data for city victor harbor
# Retrieving data for city nurota
# Retrieving data for city petropavlovka
# Retrieving data for city amli
# Retrieving data for city khanpur
# Retrieving data for city killybegs
# Retrieving data for city ciudad guayana
# Retrieving data for city santa marinella
# Retrieving data for city klimovo
# Retrieving data for city onega
# Retrieving data for city malwan
# Data for city malwan is not available
# Retrieving data for city diamantino
# Retrieving data for city holland
# Retrieving data for city arlit
# Retrieving data for city monterrey
# Retrieving data for city kununurra
# Retrieving data for city upata
# Retrieving data for city nizhniy kuranakh
# Retrieving data for city kapit
# Retrieving data for city lethem

# %%
display(df)
# Out:
#     country              city      lat       lon        date cloudiness  \
# 0        NZ             bluff -46.6000  168.3333  1643429999         91
# 1        LK          kalmunai   7.4167   81.8167  1643430332         28
# 2        PF            atuona  -9.8000 -139.0333  1643429716         10
# 3        NZ           mataura -46.1927  168.8643  1643429832         75
# 4        SA              abha  18.2164   42.5053  1643430332         20
# ..      ...               ...      ...       ...         ...        ...
# 572      AU         kununurra -15.7667  128.7333  1643430970         75
# 573      VE             upata   8.0086  -62.3989  1643431176         24
# 574      RU  nizhniy kuranakh  58.8353  125.4869  1643431196        100
# 575      MY             kapit   2.0167  112.9333  1643431196         77
# 576      GY            lethem   3.3803  -59.7968  1643431196         75
#
#     humidity  max_temp  wind_speed
# 0         63     69.80        8.05
# 1         78     80.65        4.70
# 2         78     77.67       13.82
# 3         24     69.48        7.23
# 4         87     50.25        6.91
# ..       ...       ...         ...
# 572       66     91.38       11.50
# 573       88     71.19        3.51
# 574       92     -0.49        9.06
# 575       53     91.38        1.90
# 576       66     78.08       12.44
#
# [577 rows x 9 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#The solution approach I used moved variables into a dictionary and the dictionary into a pandaframe at each city iteration
#The concat option was used to stack the dataframes after the each cities dataframe from populated.

# %%
#Export df Dataframe with cities data to the output_data folder
df.to_csv('../output_data/cities_output.csv')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_df = df[df['humidity'] > 100] 
    
print('\nResult dataframe :\n', weather_df)

#Based on the results below, none of my cities in the df (now weather_df) have humidity greater than 100.
# Out:
# Result dataframe :
#  Empty DataFrame
# Columns: [country, city, lat, lon, date, cloudiness, humidity, max_temp, wind_speed]
# Index: []

# %%
#proving or confirming for a second time thaat the humidity > 100 data frame is blank
weather_df
# Out:
# Empty DataFrame
# Columns: [country, city, lat, lon, date, cloudiness, humidity, max_temp, wind_speed]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
#Not applicable because none of my city data has humidity greater than 100 or 100%

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

#ASK TUTOR ABOUT 'inplace = false'

#Per instructions, going to make the clean_city_data into the data frame I am using

clean_city_data_df = df

display(clean_city_data_df)
# Out:
#     country              city      lat       lon        date cloudiness  \
# 0        NZ             bluff -46.6000  168.3333  1643429999         91
# 1        LK          kalmunai   7.4167   81.8167  1643430332         28
# 2        PF            atuona  -9.8000 -139.0333  1643429716         10
# 3        NZ           mataura -46.1927  168.8643  1643429832         75
# 4        SA              abha  18.2164   42.5053  1643430332         20
# ..      ...               ...      ...       ...         ...        ...
# 572      AU         kununurra -15.7667  128.7333  1643430970         75
# 573      VE             upata   8.0086  -62.3989  1643431176         24
# 574      RU  nizhniy kuranakh  58.8353  125.4869  1643431196        100
# 575      MY             kapit   2.0167  112.9333  1643431196         77
# 576      GY            lethem   3.3803  -59.7968  1643431196         75
#
#     humidity  max_temp  wind_speed
# 0         63     69.80        8.05
# 1         78     80.65        4.70
# 2         78     77.67       13.82
# 3         24     69.48        7.23
# 4         87     50.25        6.91
# ..       ...       ...         ...
# 572       66     91.38       11.50
# 573       88     71.19        3.51
# 574       92     -0.49        9.06
# 575       53     91.38        1.90
# 576       66     78.08       12.44
#
# [577 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#temp vs latitude scatterplot, format time
plt.scatter(clean_city_data_df["lat"],
            clean_city_data_df["max_temp"],
 edgecolor="black", linewidths=1, marker="o",
 alpha=1.0, label="Cities")
# Incorporate the other graph properties

#Playing around with the time.strftime() function
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
#sns is a seaborn reference - saw a youtube video and few posts about using seaborn
#Just testing it out sns.set()
sns.set(style="whitegrid")
# Save the figure
plt.savefig("../output_data/Latitude vs Temperature (F).png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#latitude vs Humidity
plt.scatter(clean_city_data_df["lat"],
 clean_city_data_df ["humidity"],
 edgecolor="black", linewidths=1, marker="o",
 alpha=0.6, label="Cities",color = "blue")
# Incorporate the other graph properties

#Playing around with the time.strftime() function
plt.title("City Latitude vs Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity")
plt.xlabel("Lat")
plt.grid(True)
sns.set(style="whitegrid")
# Save the figure
plt.savefig("../output_data/LatitudevsHumidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(clean_city_data_df['lat'], clean_city_data_df['cloudiness'], edgecolor="black", linewidths=1, marker="o",
alpha=0.7, label="Cities")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

#Playing around with the time.strftime() function
plt.title("City Latitude vs Cloudiness (%s)" % time.strftime("%x"))
sns.set(style="whitegrid")
plt.savefig("../output_data/Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(clean_city_data_df['lat'], clean_city_data_df['wind_speed'], edgecolor="black", linewidths=1, marker="o",
alpha=1.0, label="Cities")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

#Playing around with the time.strftime() function
plt.title("City Latitude vs Wind Speed (mph) (%s)" % time.strftime("%x"))
sns.set(style="whitegrid")
plt.savefig("../output_data/WindSpeed.png")

# %% [markdown]
# ## Linear Regression

# %%
#Create dataframes for the nother and southern hemispheres
north_df = clean_city_data_df.loc[pd.to_numeric(clean_city_data_df["lat"]).astype(float) > 0, :]
south_df = clean_city_data_df.loc[pd.to_numeric(clean_city_data_df["lat"]).astype(float) < 0, :]

# %%
#Review Northern DF = north_df
north_df
# Out:
#     country              city      lat       lon        date cloudiness  \
# 1        LK          kalmunai   7.4167   81.8167  1643430332         28
# 4        SA              abha  18.2164   42.5053  1643430332         20
# 5        MY        georgetown   5.4112  100.3354  1643429739         20
# 7        RU              khor  47.8861  134.9464  1643430333        100
# 10       GL         upernavik  72.7868  -56.1549  1643429990        100
# ..      ...               ...      ...       ...         ...        ...
# 571      MX         monterrey  25.6667 -100.3167  1643430915         99
# 573      VE             upata   8.0086  -62.3989  1643431176         24
# 574      RU  nizhniy kuranakh  58.8353  125.4869  1643431196        100
# 575      MY             kapit   2.0167  112.9333  1643431196         77
# 576      GY            lethem   3.3803  -59.7968  1643431196         75
#
#     humidity  max_temp  wind_speed
# 1         78     80.65        4.70
# 4         87     50.25        6.91
# 5         70     89.55        1.01
# 7         91     -3.68        6.35
# 10        71      9.12        3.36
# ..       ...       ...         ...
# 571       89     56.05        2.82
# 573       88     71.19        3.51
# 574       92     -0.49        9.06
# 575       53     91.38        1.90
# 576       66     78.08       12.44
#
# [390 rows x 9 columns]

# %%
#Review Southern DF = south_df
south_df
# Out:
#     country              city      lat       lon        date cloudiness  \
# 0        NZ             bluff -46.6000  168.3333  1643429999         91
# 2        PF            atuona  -9.8000 -139.0333  1643429716         10
# 3        NZ           mataura -46.1927  168.8643  1643429832         75
# 6        PG          lorengau  -2.0226  147.2712  1643430160         99
# 8        AU            hobart -42.8794  147.3294  1643429919         75
# ..      ...               ...      ...       ...         ...        ...
# 555      PG         namatanai  -3.6667  152.4333  1643431108        100
# 557      BR  senador guiomard -10.1522  -67.7392  1643431139        100
# 558      AU     victor harbor -35.5667  138.6167  1643431192          8
# 568      BR        diamantino -14.4086  -56.4461  1643431195        100
# 572      AU         kununurra -15.7667  128.7333  1643430970         75
#
#     humidity  max_temp  wind_speed
# 0         63     69.80        8.05
# 2         78     77.67       13.82
# 3         24     69.48        7.23
# 6         76     82.08        3.00
# 8         71     73.27        1.99
# ..       ...       ...         ...
# 555       73     84.18        5.93
# 557       98     74.95        1.19
# 558       77     84.72        1.99
# 568       97     71.98        5.14
# 572       66     91.38       11.50
#
# [187 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# using the Norhern Hemispher dataframe = north_df
#https://www.programcreek.com/python/example/84598/scipy.stats.linregress
#chart the Maximum Temp vs latitude using linear regression
x = pd.to_numeric(north_df['lat']).astype(float)
y = pd.to_numeric(north_df['max_temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress = x * slope + intercept

#define the line equation
#https://realpython.com/linear-regression-in-python/

#A linear regression line has an equation of the form Y = a + bX, 
#where X is the explanatory variable and Y is the dependent variable. 
#The slope of the line is b, and a is the intercept (the value of y when x = 0).

#http://www.stat.yale.edu/Courses/1997-98/101/linreg.htm

#linear regression is something with which I struggle or am challenged in Python and Pandas
#I googled and read several sites and posts.  I am just taking a leap that I am understanding it enough
#to put each of these pieces together.  I could have taken a more simple approach
#but I wanted to see if I could calc each component so that I could step through it
#and generate the actual equation for the slope and calc the r squared

line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot the data
plt.scatter(x,y)
plt.plot(x,regress, "r-")
plt.annotate(line_eq,(1,10),fontsize=15,color="purple")
plt.annotate(f"r squared ={rvalue}",(1,-10),fontsize=13,color="purple")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')

sns.set(style="whitegrid")

#Print the line equation and r squared
print(f"Regression line equation is: {line_eq}.")
print(f"r-squared equals: {rvalue}")

#Save the image
plt.savefig("../output_data/MaxTempvLinRegNH.png")
# Out:
# Regression line equation is: y =-1.31x + 88.04.
# r-squared equals: -0.8721220666813791

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#NOTE:For the Southern Henmisphere, I copied the code for the northern hemisphere and changed the data frame reference
#https://www.programcreek.com/python/example/84598/scipy.stats.linregress

# using the Southern Hemispher dataframe = south_df
#chart the Maximum Temp vs latitude using linear regression
x = pd.to_numeric(south_df['lat']).astype(float)
y = pd.to_numeric(south_df['max_temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress = x * slope + intercept

#define the line equation
#https://realpython.com/linear-regression-in-python/

#A linear regression line has an equation of the form Y = a + bX, 
#where X is the explanatory variable and Y is the dependent variable. 
#The slope of the line is b, and a is the intercept (the value of y when x = 0).

#http://www.stat.yale.edu/Courses/1997-98/101/linreg.htm

line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Print the line equation and r squared
print(f"Regression line equation is: {line_eq}.")
print(f"r-squared equals: {rvalue}")


#Plot the data
plt.scatter(x,y)
plt.plot(x,regress, "r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="orange")
plt.annotate(f"r squared ={rvalue}",(4,10),fontsize=13,color="orange")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')

sns.set(style="whitegrid")

#Save the image
plt.savefig("../output_data/MaxTempvLinRegSH.png")
# Out:
# Regression line equation is: y =0.28x + 80.52.
# r-squared equals: 0.3755533603523661

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Same equation written earlier for the earlier regression analysis
#https://www.programcreek.com/python/example/84598/scipy.stats.linregress
#Just need to copy and paste the original code and change the y_val to reference Humidity in the north_df

# using the Norhern Hemispher dataframe = north_df
#chart the Maximum Temp vs latitude using linear regression
x = pd.to_numeric(north_df['lat']).astype(float)
y = pd.to_numeric(north_df['humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress= x * slope + intercept

#define the line equation

line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Print the line equation and r squared
print(f"Regression line equation is: {line_eq}.")
print(f"r-squared equals: {rvalue}")


#Plot the data
plt.scatter(x,y)
plt.plot(x,regress, "r-")
plt.annotate(line_eq,(40,15),fontsize=15,color="purple")
plt.annotate(f"r squared ={rvalue}",(40,25),fontsize=13,color="purple")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Northern Hemisphere - Humidity vs. Latitude Linear Regression')

sns.set(style="whitegrid")

#Save the image
plt.savefig("../output_data/HumTempLinRegNH.png")
# Out:
# Regression line equation is: y =0.51x + 52.08.
# r-squared equals: 0.4470168579151252

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#NOTE:For the remaining southern hemisphere line regression 
#https://www.programcreek.com/python/example/84598/scipy.stats.linregress
# using the Southern Hemispher dataframe = south_df
#chart the Humidity vs latitude using linear regression
x = pd.to_numeric(south_df['lat']).astype(float)
y = pd.to_numeric(south_df['humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress = x * slope + intercept

#define the line equation
#https://realpython.com/linear-regression-in-python/

#A linear regression line has an equation of the form Y = a + bX, 
#where X is the explanatory variable and Y is the dependent variable. 
#The slope of the line is b, and a is the intercept (the value of y when x = 0).

#http://www.stat.yale.edu/Courses/1997-98/101/linreg.htm

line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Print the line equation and r squared
print(f"Regression line equation is: {line_eq}.")
print(f"r-squared equals: {rvalue}")


#Plot the data
plt.scatter(x,y)
plt.plot(x,regress, "r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="orange")
plt.annotate(f"r squared ={rvalue}",(2,-10),fontsize=13,color="orange")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Southern Hemisphere - Humidity vs. Latitude Linear Regression')

sns.set(style="whitegrid")

#Save the image
plt.savefig("../output_data/HumidityvLinRegSH.png")
# Out:
# Regression line equation is: y =0.48x + 85.2.
# r-squared equals: 0.3630165588088943

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Same equation written earlier for the earlier regression analysis
#Just need to copy and paste the original code and change the y_val to reference cloudiness in the north_df

# using the Norhern Hemispher dataframe = north_df
#chart the cloudiness vs latitude using linear regression
x = pd.to_numeric(north_df['lat']).astype(float)
y = pd.to_numeric(north_df['cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress = x * slope + intercept

#define the line equation

line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Print the line equation and r squared
print(f"Regression line equation is: {line_eq}.")
print(f"r-squared equals: {rvalue}")


#Plot the data
plt.scatter(x,y)
plt.plot(x,regress, "r-")
plt.annotate(line_eq,(45,15),fontsize=15,color="purple")
plt.annotate(f"r squared ={rvalue}",(45,25),fontsize=13,color="purple")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Northern Hemisphere - Cloudiness vs. Latitude Linear Regression')

sns.set(style="whitegrid")

#Save the image
plt.savefig("../output_data/CloudinessLinRegNH.png")
# Out:
# Regression line equation is: y =0.74x + 28.86.
# r-squared equals: 0.36757238956241545

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Same equation written earlier for the earlier regression analysis
#Just need to copy and paste the original code and change the y_val to reference cloudiness in the south_df

# using the Norhern Hemispher dataframe = north_df
#chart the cloudiness vs latitude using linear regression
x = pd.to_numeric(south_df['lat']).astype(float)
y = pd.to_numeric(south_df['cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress = x * slope + intercept

#define the line equation

line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Print the line equation and r squared
print(f"Regression line equation is: {line_eq}.")
print(f"r-squared equals: {rvalue}")


#Plot the data
plt.scatter(x,y)
plt.plot(x,regress, "r-")
plt.annotate(line_eq,(45,15),fontsize=15,color="purple")
plt.annotate(f"r squared ={rvalue}",(45,25),fontsize=13,color="purple")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Southern Hemisphere - Cloudiness vs. Latitude Linear Regression')

sns.set(style="whitegrid")

#Save the image
plt.savefig("../output_data/CloudinessLinRegSH.png")
# Out:
# Regression line equation is: y =1.49x + 91.49.
# r-squared equals: 0.46595719005934716

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Same equation written earlier for the earlier regression analysis
#Just need to copy and paste the original code and change the y_val to reference wind speed in the north_df

# using the Norhern Hemispher dataframe = north_df
#chart the Wind Speed vs latitude using linear regression
x = pd.to_numeric(north_df['lat']).astype(float)
y = pd.to_numeric(north_df['wind_speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress = x * slope + intercept

#define the line equation

line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Print the line equation and r squared
print(f"Regression line equation is: {line_eq}.")
print(f"r-squared equals: {rvalue}")


#Plot the data
plt.scatter(x,y)
plt.plot(x,regress, "r-")
plt.annotate(line_eq,(20,30),fontsize=15,color="purple")
plt.annotate(f"r squared ={rvalue}",(20,35),fontsize=13,color="purple")
plt.xlabel('Latitude')
plt.ylabel('Windspeed')
plt.title('Northern Hemisphere - Wind Speed vs. Latitude Linear Regression')

sns.set(style="whitegrid")

#Save the image
plt.savefig("../output_data/WindSpeedLinRegNH.png")
# Out:
# Regression line equation is: y =0.06x + 5.45.
# r-squared equals: 0.1834175085425351

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Same equation written earlier for the earlier regression analysis
#Just need to copy and paste the original code and change the y_val to reference wind speed in the south_df

#https://www.programcreek.com/python/example/84598/scipy.stats.linregress

# using the Norhern Hemispher dataframe = north_df
#chart the Maximum Temp vs latitude using linear regression
x_val = pd.to_numeric(south_df['lat']).astype(float)
y_val = pd.to_numeric(south_df['wind_speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_val = x_val * slope + intercept

#define the line equation

line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Print the line equation and r squared
print(f"Regression line equation is: {line_eq}.")
print(f"r-squared equals: {rvalue}")


#Plot the data
plt.scatter(x_val,y_val)
plt.plot(x_val,regress_val, "r-")
plt.annotate(line_eq,(1,1),fontsize=15,color="purple")
plt.annotate(f"r squared ={rvalue}",(1,5),fontsize=13,color="purple")
plt.xlabel('Latitude')
plt.ylabel('Windspeed')
plt.title('Southern Hemisphere - Wind Speed vs. Latitude Linear Regression')

sns.set(style="whitegrid")

#Save the image
plt.savefig("../output_data/WindSpeedLinRegSH.png")
# Out:
# Regression line equation is: y =-0.08x + 5.26.
# r-squared equals: -0.20532285144442525
