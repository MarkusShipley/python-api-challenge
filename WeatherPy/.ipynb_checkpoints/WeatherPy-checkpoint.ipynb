# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import seaborn as sns

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#Use ! in front of the code if you are running terminal commands
#!pip install seaborn
#!pip freeze 
#!pip install citipy

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 644

# %%
#Just to check the cities in the list
print(cities)
# Out:
# ['qaanaaq', 'nikolskoye', 'bengkulu', 'menomonie', 'hithadhoo', 'puerto ayora', 'ishigaki', 'manakara', 'new norfolk', 'ribeira grande', 'san patricio', 'luanda', 'mataura', 'punta arenas', 'hanstholm', 'yellowknife', 'codrington', 'thompson', 'mergui', 'butaritari', 'aljezur', 'nisia floresta', 'huarmey', 'am timan', 'koundara', 'derzhavinsk', 'georgetown', 'victoria', 'hutchinson', 'tambura', 'vaini', 'bela', 'monmouth', 'dunedin', 'la rioja', 'tuktoyaktuk', 'cape town', 'alofi', 'mar del plata', 'fortuna', 'calama', 'kindu', 'gubkinskiy', 'iquitos', 'kavaratti', 'ushuaia', 'rikitea', 'kamaishi', 'avera', 'jamestown', 'carnarvon', 'kazanka', 'lagos', 'kodiak', 'rawannawi', 'tasiilaq', 'atuona', 'margate', 'aginskoye', 'kapaa', 'comodoro rivadavia', 'taolanaro', 'hilo', 'korla', 'new castle', 'albany', 'port blair', 'lebu', 'hermanus', 'busselton', 'bluff', 'suoyarvi', 'husavik', 'barrow', 'khandyga', 'henties bay', 'saskylakh', 'port augusta', 'flin flon', 'tuatapere', 'chumikan', 'anadyr', 'chuy', 'green river', 'bagn', 'bredasdorp', 'norman wells', 'nikki', 'belushya guba', 'iralaya', 'hanzhong', 'airai', 'la ronge', 'arraial do cabo', 'meadow lake', 'termiz', 'lavrentiya', 'altay', 'cherskiy', 'paoua', 'aban', 'bonavista', 'kahului', 'barentsburg', 'saleaula', 'geraldton', 'hesla', 'assiniboia', 'bam', 'bagnes', 'caravelas', 'sassandra', 'virginia beach', 'yulara', 'egvekinot', 'ewa beach', 'nsoko', 'lekhaina', 'sorong', 'castro', 'bajo baudo', 'ngaoundere', 'odweyne', 'kungurtug', 'manta', 'narsaq', 'rosetta', 'east london', 'umzimvubu', 'saint-philippe', 'teruel', 'luderitz', 'ponta do sol', 'kitgum', 'asfi', 'tura', 'changli', 'bethel', 'baoning', 'westport', 'vila', 'port alfred', 'san cristobal', 'clovis', 'proletariy', 'de aar', 'mayo', 'daru', 'sataua', 'longyearbyen', 'jawhar', 'chokurdakh', 'boke', 'contamana', 'byron bay', 'kurilsk', 'cidreira', 'houma', 'padang', 'sorland', 'daman', 'sayan', 'mahebourg', 'can', 'kabare', 'ust-karsk', 'isangel', 'porciuncula', 'scarborough', 'bambous virieux', 'necochea', 'beloha', 'hobart', 'kaitangata', 'maniitsoq', 'seddon', 'kirakira', 'bucerias', 'cayenne', 'charters towers', 'bossangoa', 'kenai', 'dharchula', 'faanui', 'burica', 'mogadishu', 'mvuma', 'tame', 'samusu', 'hamilton', 'sao filipe', 'hasaki', 'phan rang', 'fethiye', 'kagoro', 'sentyabrskiy', 'botou', 'amderma', 'meyungs', 'pangoa', 'aquiraz', 'honningsvag', 'port hardy', 'svetlyy', 'ylivieska', 'taree', 'merke', 'boa vista', 'alice springs', 'dedham', 'mys shmidta', 'poum', 'srednekolymsk', 'wanaka', 'albanel', 'elko', 'grand gaube', 'avarua', 'kavieng', 'bredy', 'tautira', 'kargopol', 'dolgoderevenskoye', 'fallon', 'huilong', 'crib point', 'naze', 'te anau', 'aquin', 'aksu', 'ucluelet', 'port elizabeth', 'grand river south east', 'marsa matruh', 'alta floresta', 'ahipara', 'roald', 'lukulu', 'provideniya', 'yuancheng', 'kyotera', 'sevierville', 'starokucherganovka', 'waipawa', 'komsomolskiy', 'port macquarie', 'palafrugell', 'verdun', 'severo-kurilsk', 'yar-sale', 'buqayq', 'grootfontein', 'vieste', 'ullapool', 'ojinaga', 'farkhor', 'gbadolite', 'mount gambier', 'inta', 'mangaratiba', 'waddan', 'praia', 'baykit', 'albury', 'salalah', 'russell', 'sakakah', 'khatanga', 'tiksi', 'namibe', 'haines junction', 'maragogi', 'college', 'vila velha', 'nome', 'cuamba', 'srednebelaya', 'yirol', 'kodinsk', 'cabo san lucas', 'ouallam', 'malkangiri', 'dauriya', 'bathsheba', 'mutis', 'illoqqortoormiut', 'payo', 'kingaroy', 'tanout', 'mae sai', 'yanchukan', 'ercis', 'sitka', 'pacifica', 'matara', 'ayabaca', 'okhotsk', 'wajima', 'hami', 'pacific grove', 'ossora', 'jalu', 'ust-kamchatsk', 'kundiawa', 'udachnyy', 'esperance', 'portland', 'okha', 'abha', 'tsihombe', 'yangambi', 'ducheng', 'atar', 'dikson', 'gat', 'guerrero negro', 'lagoa', 'soderhamn', 'aklavik', 'klaksvik', 'ouadda', 'grafenhainichen', 'caratinga', 'goundam', 'mount isa', 'torbay', 'cervignano del friuli', 'watsa', 'tarakan', 'pingzhuang', 'pedasi', 'nanortalik',  ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).
#
# > **HINT:** The OpenWeatherMap API only allows 60 calls per minute under their free plan. Try using `time.sleep(60)` after each set of 50 cities to avoid API errors due to large calls.

# %%
#Openweather API Calls
url = "http://api.openweathermap.org/data/2.5/weather?"
#The open weather API requires units as a parameter
unit_parameter = "imperial"

# Build partial query URL and use sample city to test
query_url_test = f"{url}appid={weather_api_key}&units={unit_parameter}&q=Knoxville"
#Commented out the display (query_url) after testing because display revealed the keys in the url
#display (query_url_test)

# %%
#Partial QUery from Test Section Above
query_url= f"{url}appid={weather_api_key}&units={unit_parameter}&q="
#Commented out the display (query_url) after testing because display revealed the keys in the url
#display (query_url)

# %%
#Creating an empty dataframe
df = pd.DataFrame(columns=['country', 'city', 'lat', 'lon', 'date', 'cloudiness', 'humidity', 'max_temp', 'wind_speed'])

display(df)
# Out:
# Empty DataFrame
# Columns: [country, city, lat, lon, date, cloudiness, humidity, max_temp, wind_speed]
# Index: []

# %%
#Building the query
#I knew the query would would generate the correct results after the testing above using Knoxville.
query_url= f"{url}appid={weather_api_key}&units={unit_parameter}&q="

# %%
count = 1

for city in cities:
    if count % 50 == 0:
        time.sleep(60)
    try:
        print(f'Retrieving data for city {city}')
        #Get values for current city
        city_info = requests.get(query_url + city).json()
        country = city_info['sys']['country']
        date = city_info['dt']
        lat = city_info['coord']['lat']
        lon = city_info['coord']['lon']
        clouds = city_info['clouds']['all']
        humidity = city_info['main']['humidity']
        max_temp = city_info['main']['temp_max']
        wind_speed = city_info['wind']['speed']
        
        #Create a dictionary
        current_city_dict = {
            'country': country,
            'city': city,
            'lat': lat,
            'lon': lon,
            'date': date,
            'cloudiness': clouds,
            'humidity': humidity,
            'max_temp': max_temp,
            'wind_speed': wind_speed
        }
        
        #Convert dictionary to dataframe for current city
        current_city = pd.DataFrame([current_city_dict])
        
        #Concatenate main df with current city dataframe
        df = pd.concat([df, current_city]).reset_index(drop=True)
        
    except:
        print(f'Data for city {city} is not available')
    
    count+=1
# Out:
# Retrieving data for city qaanaaq
# Retrieving data for city nikolskoye
# Retrieving data for city bengkulu
# Retrieving data for city menomonie
# Retrieving data for city hithadhoo
# Retrieving data for city puerto ayora
# Retrieving data for city ishigaki
# Retrieving data for city manakara
# Retrieving data for city new norfolk
# Retrieving data for city ribeira grande
# Retrieving data for city san patricio
# Retrieving data for city luanda
# Retrieving data for city mataura
# Retrieving data for city punta arenas
# Retrieving data for city hanstholm
# Retrieving data for city yellowknife
# Retrieving data for city codrington
# Retrieving data for city thompson
# Retrieving data for city mergui
# Data for city mergui is not available
# Retrieving data for city butaritari
# Retrieving data for city aljezur
# Retrieving data for city nisia floresta
# Retrieving data for city huarmey
# Retrieving data for city am timan
# Retrieving data for city koundara
# Retrieving data for city derzhavinsk
# Retrieving data for city georgetown
# Retrieving data for city victoria
# Retrieving data for city hutchinson
# Retrieving data for city tambura
# Retrieving data for city vaini
# Retrieving data for city bela
# Retrieving data for city monmouth
# Retrieving data for city dunedin
# Retrieving data for city la rioja
# Retrieving data for city tuktoyaktuk
# Retrieving data for city cape town
# Retrieving data for city alofi
# Retrieving data for city mar del plata
# Retrieving data for city fortuna
# Retrieving data for city calama
# Retrieving data for city kindu
# Retrieving data for city gubkinskiy
# Retrieving data for city iquitos
# Retrieving data for city kavaratti
# Retrieving data for city ushuaia
# Retrieving data for city rikitea
# Retrieving data for city kamaishi
# Retrieving data for city avera
# Retrieving data for city jamestown
# Retrieving data for city carnarvon
# Retrieving data for city kazanka
# Retrieving data for city lagos
# Retrieving data for city kodiak
# Retrieving data for city rawannawi
# Data for city rawannawi is not available
# Retrieving data for city tasiilaq
# Retrieving data for city atuona
# Retrieving data for city margate
# Retrieving data for city aginskoye
# Retrieving data for city kapaa
# Retrieving data for city comodoro rivadavia
# Retrieving data for city taolanaro
# Data for city taolanaro is not available
# Retrieving data for city hilo
# Retrieving data for city korla
# Retrieving data for city new castle
# Retrieving data for city albany
# Retrieving data for city port blair
# Retrieving data for city lebu
# Retrieving data for city hermanus
# Retrieving data for city busselton
# Retrieving data for city bluff
# Retrieving data for city suoyarvi
# Retrieving data for city husavik
# Retrieving data for city barrow
# Retrieving data for city khandyga
# Retrieving data for city henties bay
# Retrieving data for city saskylakh
# Retrieving data for city port augusta
# Retrieving data for city flin flon
# Retrieving data for city tuatapere
# Retrieving data for city chumikan
# Retrieving data for city anadyr
# Retrieving data for city chuy
# Retrieving data for city green river
# Retrieving data for city bagn
# Retrieving data for city bredasdorp
# Retrieving data for city norman wells
# Retrieving data for city nikki
# Retrieving data for city belushya guba
# Data for city belushya guba is not available
# Retrieving data for city iralaya
# Retrieving data for city hanzhong
# Retrieving data for city airai
# Retrieving data for city la ronge
# Retrieving data for city arraial do cabo
# Retrieving data for city meadow lake
# Retrieving data for city termiz
# Retrieving data for city lavrentiya
# Retrieving data for city altay
# Retrieving data for city cherskiy
# Retrieving data for city paoua
# Retrieving data for city aban
# Retrieving data for city bonavista
# Retrieving data for city kahului
# Retrieving data for city barentsburg
# Data for city barentsburg is not available
# Retrieving data for city saleaula
# Data for city saleaula is not available
# Retrieving data for city geraldton
# Retrieving data for city hesla
# Retrieving data for city assiniboia
# Retrieving data for city bam
# Retrieving data for city bagnes
# Retrieving data for city caravelas
# Retrieving data for city sassandra
# Retrieving data for city virginia beach
# Retrieving data for city yulara
# Retrieving data for city egvekinot
# Retrieving data for city ewa beach
# Retrieving data for city nsoko
# Retrieving data for city lekhaina
# Data for city lekhaina is not available
# Retrieving data for city sorong
# Retrieving data for city castro
# Retrieving data for city bajo baudo
# Data for city bajo baudo is not available
# Retrieving data for city ngaoundere
# Retrieving data for city odweyne
# Retrieving data for city kungurtug
# Retrieving data for city manta
# Retrieving data for city narsaq
# Retrieving data for city rosetta
# Retrieving data for city east london
# Retrieving data for city umzimvubu
# Data for city umzimvubu is not available
# Retrieving data for city saint-philippe
# Retrieving data for city teruel
# Retrieving data for city luderitz
# Retrieving data for city ponta do sol
# Retrieving data for city kitgum
# Retrieving data for city asfi
# Retrieving data for city tura
# Retrieving data for city changli
# Retrieving data for city bethel
# Retrieving data for city baoning
# Retrieving data for city westport
# Retrieving data for city vila
# Retrieving data for city port alfred
# Retrieving data for city san cristobal
# Retrieving data for city clovis
# Retrieving data for city proletariy
# Retrieving data for city de aar
# Retrieving data for city mayo
# Retrieving data for city daru
# Retrieving data for city sataua
# Data for city sataua is not available
# Retrieving data for city longyearbyen
# Retrieving data for city jawhar
# Retrieving data for city chokurdakh
# Retrieving data for city boke
# Retrieving data for city contamana
# Retrieving data for city byron bay
# Retrieving data for city kurilsk
# Retrieving data for city cidreira
# Retrieving data for city houma
# Retrieving data for city padang
# Retrieving data for city sorland
# Retrieving data for city daman
# Retrieving data for city sayan
# Retrieving data for city mahebourg
# Retrieving data for city can
# Retrieving data for city kabare
# Retrieving data for city ust-karsk
# Retrieving data for city isangel
# Retrieving data for city porciuncula
# Retrieving data for city scarborough
# Retrieving data for city bambous virieux
# Retrieving data for city necochea
# Retrieving data for city beloha
# Retrieving data for city hobart
# Retrieving data for city kaitangata
# Retrieving data for city maniitsoq
# Retrieving data for city seddon
# Retrieving data for city kirakira
# Retrieving data for city bucerias
# Retrieving data for city cayenne
# Retrieving data for city charters towers
# Retrieving data for city bossangoa
# Retrieving data for city kenai
# Retrieving data for city dharchula
# Retrieving data for city faanui
# Retrieving data for city burica
# Data for city burica is not available
# Retrieving data for city mogadishu
# Retrieving data for city mvuma
# Retrieving data for city tame
# Retrieving data for city samusu
# Data for city samusu is not available
# Retrieving data for city hamilton
# Retrieving data for city sao filipe
# Retrieving data for city hasaki
# Retrieving data for city phan rang
# Data for city phan rang is not available
# Retrieving data for city fethiye
# Retrieving data for city kagoro
# Retrieving data for city sentyabrskiy
# Data for city sentyabrskiy is not available
# Retrieving data for city botou
# Retrieving data for city amderma
# Data for city amderma is not available
# Retrieving data for city meyungs
# Data for city meyungs is not available
# Retrieving data for city pangoa
# Retrieving data for city aquiraz
# Retrieving data for city honningsvag
# Retrieving data for city port hardy
# Retrieving data for city svetlyy
# Retrieving data for city ylivieska
# Retrieving data for city taree
# Retrieving data for city merke
# Retrieving data for city boa vista
# Retrieving data for city alice springs
# Retrieving data for city dedham
# Retrieving data for city mys shmidta
# Data for city mys shmidta is not available
# Retrieving data for city poum
# Retrieving data for city srednekolymsk
# Retrieving data for city wanaka
# Retrieving data for city albanel
# Retrieving data for city elko
# Retrieving data for city grand gaube
# Retrieving data for city avarua
# Retrieving data for city kavieng
# Retrieving data for city bredy
# Retrieving data for city tautira
# Retrieving data for city kargopol
# Retrieving data for city dolgoderevenskoye
# Retrieving data for city fallon
# Retrieving data for city huilong
# Retrieving data for city crib point
# Retrieving data for city naze
# Retrieving data for city te anau
# Retrieving data for city aquin
# Retrieving data for city aksu
# Retrieving data for city ucluelet
# Retrieving data for city port elizabeth
# Retrieving data for city grand river south east
# Data for city grand river south east is not available
# Retrieving data for city marsa matruh
# Retrieving data for city alta floresta
# Retrieving data for city ahipara
# Retrieving data for city roald
# Retrieving data for city lukulu
# Retrieving data for city provideniya
# Retrieving data for city yuancheng
# Retrieving data for city kyotera
# Retrieving data for city sevierville
# Retrieving data for city starokucherganovka
# Retrieving data for city waipawa
# Retrieving data for city komsomolskiy
# Retrieving data for city port macquarie
# Retrieving data for city palafrugell
# Retrieving data for city verdun
# Retrieving data for city severo-kurilsk
# Retrieving data for city yar-sale
# Retrieving data for city buqayq
# Data for city buqayq is not available
# Retrieving data for city grootfontein
# Retrieving data for city vieste
# Retrieving data for city ullapool
# Retrieving data for city ojinaga
# Retrieving data for city farkhor
# Retrieving data for city gbadolite
# Retrieving data for city mount gambier
# Retrieving data for city inta
# Retrieving data for city mangaratiba
# Retrieving data for city waddan
# Retrieving data for city praia
# Retrieving data for city baykit
# Retrieving data for city albury
# Retrieving data for city salalah
# Retrieving data for city russell
# Retrieving data for city sakakah
# Retrieving data for city khatanga
# Retrieving data for city tiksi
# Retrieving data for city namibe
# Retrieving data for city haines junction
# Retrieving data for city maragogi
# Retrieving data for city college
# Retrieving data for city vila velha
# Retrieving data for city nome
# Retrieving data for city cuamba
# Retrieving data for city srednebelaya
# Retrieving data for city yirol
# Data for city yirol is not available
# Retrieving data for city kodinsk
# Retrieving data for city cabo san lucas
# Retrieving data for city ouallam
# Retrieving data for city malkangiri
# Retrieving data for city dauriya
# Retrieving data for city bathsheba
# Retrieving data for city mutis
# Retrieving data for city illoqqortoormiut
# Data for city illoqqortoormiut is not available
# Retrieving data for city payo
# Retrieving data for city kingaroy
# Retrieving data for city tanout
# Retrieving data for city mae sai
# Retrieving data for city yanchukan
# Data for city yanchukan is not available
# Retrieving data for city ercis
# Retrieving data for city sitka
# Retrieving data for city pacifica
# Retrieving data for city matara
# Retrieving data for city ayabaca
# Retrieving data for city okhotsk
# Retrieving data for city wajima
# Retrieving data for city hami
# Retrieving data for city pacific grove
# Retrieving data for city ossora
# Retrieving data for city jalu
# Retrieving data for city ust-kamchatsk
# Data for city ust-kamchatsk is not available
# Retrieving data for city kundiawa
# Retrieving data for city udachnyy
# Retrieving data for city esperance
# Retrieving data for city portland
# Retrieving data for city okha
# Retrieving data for city abha
# Retrieving data for city tsihombe
# Data for city tsihombe is not available
# Retrieving data for city yangambi
# Retrieving data for city ducheng
# Retrieving data for city atar
# Retrieving data for city dikson
# Retrieving data for city gat
# Retrieving data for city guerrero negro
# Retrieving data for city lagoa
# Retrieving data for city soderhamn
# Retrieving data for city aklavik
# Retrieving data for city klaksvik
# Retrieving data for city ouadda
# Retrieving data for city grafenhainichen
# Retrieving data for city caratinga
# Retrieving data for city goundam
# Retrieving data for city mount isa
# Retrieving data for city torbay
# Retrieving data for city cervignano del friuli
# Retrieving data for city watsa
# Retrieving data for city tarakan
# Retrieving data for city pingzhuang
# Retrieving data for city pedasi
# Retrieving data for city nanortalik
# Retrieving data for city warrington
# Retrieving data for city capitan bado
# Retrieving data for city pottsville
# Retrieving data for city boden
# Retrieving data for city serenje
# Retrieving data for city marcona
# Data for city marcona is not available
# Retrieving data for city grand centre
# Data for city grand centre is not available
# Retrieving data for city ahuimanu
# Retrieving data for city pisco
# Retrieving data for city vestmannaeyjar
# Retrieving data for city verkhnevilyuysk
# Retrieving data for city bowen
# Retrieving data for city sambava
# Retrieving data for city ilulissat
# Retrieving data for city igarape-miri
# Data for city igarape-miri is not available
# Retrieving data for city micheweni
# Retrieving data for city katsuura
# Retrieving data for city puro
# Retrieving data for city keti bandar
# Retrieving data for city maraa
# Retrieving data for city weligama
# Retrieving data for city nurota
# Retrieving data for city riyadh
# Retrieving data for city mayumba
# Retrieving data for city doaba
# Retrieving data for city dong hoi
# Retrieving data for city tamiahua
# Retrieving data for city hauterive
# Retrieving data for city berga
# Retrieving data for city kaeo
# Retrieving data for city lompoc
# Retrieving data for city morondava
# Retrieving data for city samarai
# Retrieving data for city kruisfontein
# Retrieving data for city karangampel
# Retrieving data for city nizhneyansk
# Data for city nizhneyansk is not available
# Retrieving data for city bury saint edmunds
# Data for city bury saint edmunds is not available
# Retrieving data for city pakokku
# Retrieving data for city chapleau
# Retrieving data for city laguna
# Retrieving data for city hanyang
# Retrieving data for city gangotri
# Data for city gangotri is not available
# Retrieving data for city port moresby
# Retrieving data for city hendersonville
# Retrieving data for city pochutla
# Retrieving data for city cockburn town
# Retrieving data for city renfrew
# Retrieving data for city kyra
# Retrieving data for city fukue
# Retrieving data for city ola
# Retrieving data for city saldanha
# Retrieving data for city vaitupu
# Data for city vaitupu is not available
# Retrieving data for city cururupu
# Retrieving data for city broken hill
# Retrieving data for city surt
# Retrieving data for city volgodonsk
# Retrieving data for city soltsy
# Retrieving data for city warqla
# Data for city warqla is not available
# Retrieving data for city port hedland
# Retrieving data for city san carlos de bariloche
# Retrieving data for city kulhudhuffushi
# Retrieving data for city hambantota
# Retrieving data for city bintulu
# Retrieving data for city saint george
# Retrieving data for city coihueco
# Retrieving data for city lata
# Retrieving data for city samalaeulu
# Data for city samalaeulu is not available
# Retrieving data for city faro
# Retrieving data for city muskogee
# Retrieving data for city passo fundo
# Retrieving data for city iqaluit
# Retrieving data for city tipacoque
# Retrieving data for city artigas
# Retrieving data for city tumannyy
# Data for city tumannyy is not available
# Retrieving data for city norrtalje
# Retrieving data for city sabang
# Retrieving data for city acapulco
# Retrieving data for city kattivakkam
# Retrieving data for city terekli-mekteb
# Retrieving data for city karamea
# Data for city karamea is not available
# Retrieving data for city fort morgan
# Retrieving data for city humberto de campos
# Retrieving data for city chodavaram
# Retrieving data for city angangxi
# Data for city angangxi is not available
# Retrieving data for city sisimiut
# Retrieving data for city touros
# Retrieving data for city darhan
# Retrieving data for city teeli
# Retrieving data for city hofn
# Retrieving data for city pocatello
# Retrieving data for city fort nelson
# Retrieving data for city sijunjung
# Retrieving data for city chapais
# Retrieving data for city hargeysa
# Retrieving data for city kijang
# Retrieving data for city karratha
# Retrieving data for city dakar
# Retrieving data for city buala
# Retrieving data for city sulangan
# Retrieving data for city ambodifototra
# Data for city ambodifototra is not available
# Retrieving data for city moron
# Retrieving data for city barcelos
# Retrieving data for city marystown
# Retrieving data for city chivilcoy
# Retrieving data for city pevek
# Retrieving data for city ukiah
# Retrieving data for city zhaotong
# Retrieving data for city kontagora
# Retrieving data for city tecoanapa
# Retrieving data for city semey
# Retrieving data for city lawton
# Retrieving data for city ancud
# Retrieving data for city sao joao da barra
# Retrieving data for city saryshagan
# Data for city saryshagan is not available
# Retrieving data for city tessalit
# Retrieving data for city upington
# Retrieving data for city ayagoz
# Retrieving data for city navolato
# Retrieving data for city skalistyy
# Data for city skalistyy is not available
# Retrieving data for city bretcu
# Retrieving data for city xai-xai
# Retrieving data for city ballina
# Retrieving data for city gedangan
# Retrieving data for city adrar
# Retrieving data for city norwich
# Retrieving data for city dolbeau
# Data for city dolbeau is not available
# Retrieving data for city haibowan
# Data for city haibowan is not available
# Retrieving data for city ixtapa
# Retrieving data for city san andres
# Retrieving data for city paamiut
# Retrieving data for city olafsvik
# Retrieving data for city ketchikan
# Retrieving data for city port-gentil
# Retrieving data for city sibolga
# Retrieving data for city asau
# Retrieving data for city cabedelo
# Retrieving data for city chagda
# Data for city chagda is not available
# Retrieving data for city moose factory
# Retrieving data for city boguchany
# Retrieving data for city marzuq
# Retrieving data for city fort saint john
# Data for city fort saint john is not available
# Retrieving data for city plettenberg bay
# Retrieving data for city azul
# Retrieving data for city rancharia
# Retrieving data for city coruripe
# Retrieving data for city racale
# Retrieving data for city viligili
# Data for city viligili is not available
# Retrieving data for city miles city
# Retrieving data for city presidencia roque saenz pena
# Retrieving data for city kharan
# Retrieving data for city meulaboh
# Retrieving data for city shelby
# Retrieving data for city rocha
# Retrieving data for city yumen
# Retrieving data for city talisayan
# Retrieving data for city mansfield
# Retrieving data for city monte alegre
# Retrieving data for city sovetskiy
# Retrieving data for city uglegorsk
# Retrieving data for city teahupoo
# Retrieving data for city coquimbo
# Retrieving data for city susani
# Retrieving data for city limbang
# Retrieving data for city san felipe
# Retrieving data for city jhalida
# Retrieving data for city rawson
# Retrieving data for city grindavik
# Retrieving data for city sioux lookout
# Retrieving data for city vao
# Retrieving data for city rome
# Retrieving data for city loreto
# Retrieving data for city barcarena
# Retrieving data for city kerchevskiy
# Retrieving data for city maceio
# Retrieving data for city bereda
# Retrieving data for city tungkang
# Data for city tungkang is not available
# Retrieving data for city tahta
# Retrieving data for city kupang
# Retrieving data for city leningradskiy
# Retrieving data for city san policarpo
# Retrieving data for city carora
# Retrieving data for city port hawkesbury
# Retrieving data for city pasinler
# Retrieving data for city palana
# Retrieving data for city souillac
# Retrieving data for city hervey bay
# Retrieving data for city ouargaye
# Retrieving data for city thunder bay
# Retrieving data for city faya
# Retrieving data for city galle
# Retrieving data for city goderich
# Retrieving data for city beringovskiy
# Retrieving data for city bemidji
# Retrieving data for city vanavara
# Retrieving data for city conceicao das alagoas
# Retrieving data for city manokwari
# Retrieving data for city murray bridge
# Retrieving data for city martapura
# Retrieving data for city bardejov
# Retrieving data for city san juan
# Retrieving data for city guarapuava
# Retrieving data for city natal
# Retrieving data for city chicama
# Retrieving data for city poso
# Retrieving data for city evensk
# Retrieving data for city vardo
# Retrieving data for city san-pedro
# Retrieving data for city maraba
# Retrieving data for city rosario
# Retrieving data for city north bend
# Retrieving data for city pacasmayo
# Retrieving data for city tawang
# Retrieving data for city lovozero
# Retrieving data for city borama
# Data for city borama is not available
# Retrieving data for city samana
# Retrieving data for city newport
# Retrieving data for city poya
# Retrieving data for city manama
# Retrieving data for city pakxe
# Retrieving data for city wilmington
# Retrieving data for city arman
# Retrieving data for city brae
# Retrieving data for city zlatoustovsk
# Data for city zlatoustovsk is not available
# Retrieving data for city ihosy
# Retrieving data for city chabahar
# Retrieving data for city tabou
# Retrieving data for city dingle
# Retrieving data for city rancho palos verdes
# Retrieving data for city ulladulla
# Retrieving data for city tuy hoa
# Retrieving data for city mecca
# Retrieving data for city baiyin
# Retrieving data for city upernavik
# Retrieving data for city whitehorse
# Retrieving data for city tongliao
# Retrieving data for city dondo
# Retrieving data for city hay river
# Retrieving data for city tipuani
# Retrieving data for city shache
# Retrieving data for city kaliganj
# Retrieving data for city lasa
# Retrieving data for city pergamino
# Retrieving data for city valdosta
# Retrieving data for city birao
# Retrieving data for city meiganga
# Retrieving data for city kununurra
# Retrieving data for city rio grande
# Retrieving data for city bandarbeyla
# Retrieving data for city alekseyevsk
# Retrieving data for city valleyview
# Retrieving data for city kosonsoy
# Retrieving data for city hihifo
# Data for city hihifo is not available
# Retrieving data for city ahumada
# Data for city ahumada is not available
# Retrieving data for city shrewsbury
# Retrieving data for city kamuli
# Retrieving data for city kosh-agach
# Retrieving data for city kalmunai
# Retrieving data for city bestobe
# Retrieving data for city abu kamal
# Retrieving data for city srandakan
# Retrieving data for city sao mateus do maranhao
# Retrieving data for city pontal do parana
# Retrieving data for city nioro
# Retrieving data for city svencionys
# Retrieving data for city preobrazheniye
# Retrieving data for city okato
# Retrieving data for city bathurst
# Retrieving data for city dedza
# Retrieving data for city novo aripuana
# Retrieving data for city coswig
# Retrieving data for city miri
# Retrieving data for city vila franca do campo
# Retrieving data for city nabire
# Retrieving data for city gorontalo
# Retrieving data for city amahai
# Retrieving data for city solovetskiy
# Data for city solovetskiy is not available
# Retrieving data for city filingue
# Retrieving data for city fereydun kenar
# Retrieving data for city falealupo
# Data for city falealupo is not available
# Retrieving data for city grafton
# Retrieving data for city patitirion
# Retrieving data for city jiddah
# Data for city jiddah is not available
# Retrieving data for city khovu-aksy
# Retrieving data for city pokhara
# Retrieving data for city reconquista
# Retrieving data for city orlik
# Retrieving data for city sangar
# Retrieving data for city mega
# Retrieving data for city riviere-du-loup
# Retrieving data for city zhicheng
# Retrieving data for city pandan
# Retrieving data for city higuey
# Data for city higuey is not available
# Retrieving data for city mehamn
# Retrieving data for city pachperwa
# Retrieving data for city chapeco
# Retrieving data for city teguise
# Retrieving data for city villa bruzual
# Retrieving data for city port lincoln
# Retrieving data for city havre
# Retrieving data for city lufkin
# Retrieving data for city kaohsiung
# Retrieving data for city coffs harbour
# Retrieving data for city kondinskoye
# Retrieving data for city andenes
# Data for city andenes is not available
# Retrieving data for city mazagao
# Retrieving data for city tilichiki
# Retrieving data for city deputatskiy
# Retrieving data for city lorengau
# Retrieving data for city gashua
# Retrieving data for city wahiawa
# Retrieving data for city saint-georges
# Retrieving data for city firozpur jhirka

# %%
display(df)
# Out:
#     country             city      lat       lon        date cloudiness  \
# 0        GL          qaanaaq  77.4840  -69.3632  1643577032        100
# 1        RU       nikolskoye  59.7035   30.7861  1643577032        100
# 2        ID         bengkulu  -3.8004  102.2655  1643577032        100
# 3        US        menomonie  44.8755  -91.9193  1643577033        100
# 4        MV        hithadhoo  -0.6000   73.0833  1643576866         81
# ..      ...              ...      ...       ...         ...        ...
# 585      PG         lorengau  -2.0226  147.2712  1643577957        100
# 586      NG           gashua  12.8710   11.0482  1643578020         18
# 587      US          wahiawa  21.5028 -158.0236  1643578020         75
# 588      GD    saint-georges  12.0564  -61.7485  1643578021         20
# 589      IN  firozpur jhirka  27.8000   76.9500  1643578021          0
#
#     humidity  max_temp  wind_speed
# 0         67     -7.91        6.64
# 1         95     27.39        6.73
# 2         89     75.97        3.27
# 3         63     26.65        3.44
# 4         70     81.61        9.04
# ..       ...       ...         ...
# 585       87     78.30       12.01
# 586       14     64.99       10.38
# 587       61     75.87        9.22
# 588       74     82.08       14.97
# 589       44     53.47        1.92
#
# [590 rows x 9 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#The solution approach I used moved variables into a dictionary and the dictionary into a pandaframe at each city iteration
#The concat option was used to stack the dataframes after the each cities dataframe from populated.

# %%
#Export df Dataframe with cities data to the output_data folder
df.to_csv('../output_data/cities_output.csv')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_df = df[df['humidity'] > 100] 
    
print('\nResult dataframe :\n', weather_df)

#Based on the results below, none of my cities in the df (now weather_df) have humidity greater than 100.
# Out:
# Result dataframe :
#  Empty DataFrame
# Columns: [country, city, lat, lon, date, cloudiness, humidity, max_temp, wind_speed]
# Index: []

# %%
#proving or confirming for a second time thaat the humidity > 100 data frame is blank
weather_df
# Out:
# Empty DataFrame
# Columns: [country, city, lat, lon, date, cloudiness, humidity, max_temp, wind_speed]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
#Not applicable because none of my city data has humidity greater than 100 or 100%

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

#Per instructions, going to make the clean_city_data into the data frame I am using

clean_city_data_df = df

display(clean_city_data_df)
# Out:
#     country             city      lat       lon        date cloudiness  \
# 0        GL          qaanaaq  77.4840  -69.3632  1643577032        100
# 1        RU       nikolskoye  59.7035   30.7861  1643577032        100
# 2        ID         bengkulu  -3.8004  102.2655  1643577032        100
# 3        US        menomonie  44.8755  -91.9193  1643577033        100
# 4        MV        hithadhoo  -0.6000   73.0833  1643576866         81
# ..      ...              ...      ...       ...         ...        ...
# 585      PG         lorengau  -2.0226  147.2712  1643577957        100
# 586      NG           gashua  12.8710   11.0482  1643578020         18
# 587      US          wahiawa  21.5028 -158.0236  1643578020         75
# 588      GD    saint-georges  12.0564  -61.7485  1643578021         20
# 589      IN  firozpur jhirka  27.8000   76.9500  1643578021          0
#
#     humidity  max_temp  wind_speed
# 0         67     -7.91        6.64
# 1         95     27.39        6.73
# 2         89     75.97        3.27
# 3         63     26.65        3.44
# 4         70     81.61        9.04
# ..       ...       ...         ...
# 585       87     78.30       12.01
# 586       14     64.99       10.38
# 587       61     75.87        9.22
# 588       74     82.08       14.97
# 589       44     53.47        1.92
#
# [590 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#temp vs latitude scatterplot, format time
plt.scatter(clean_city_data_df["lat"],
            clean_city_data_df["max_temp"],
 edgecolor="black", linewidths=1, marker="o",
 alpha=1.0, label="Cities")
# Incorporate the other graph properties

#Playing around with the time.strftime() function
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
#sns is a seaborn reference - saw a youtube video and few posts about using seaborn
#Just testing it out sns.set()
sns.set(style="whitegrid")
# Save the figure
plt.savefig("../output_data/Latitude vs Temperature (F).png")

# %% [markdown]
# Nothern Hemisphere has a latitude of > 0 and Southern Hemisphere has a latitude < 0.  The Equator is refelcted at 0 latitude.
# The scatter plot above reflects that the closer we move from the Northern Hemisphere. the more temperatures increase.  Based on the data generated in the exercise, we are not seeing a significant or only minor change in the southern hemisphere as we move away from the equator

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#latitude vs Humidity
plt.scatter(clean_city_data_df["lat"],
 clean_city_data_df ["humidity"],
 edgecolor="black", linewidths=1, marker="o",
 alpha=0.6, label="Cities",color = "blue")
# Incorporate the other graph properties

#Playing around with the time.strftime() function
plt.title("City Latitude vs Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity")
plt.xlabel("Lat")
plt.grid(True)
sns.set(style="whitegrid")
# Save the figure
plt.savefig("../output_data/LatitudevsHumidity.png")

# %% [markdown]
# The "City Latitude vs Humidity" scatter plot shown above analyzes hmidity values as we move nearer and further away from the equator.  The chart clearly reflects that humidity levels have little impact based on proximity to the equator.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(clean_city_data_df['lat'], clean_city_data_df['cloudiness'], edgecolor="black", linewidths=1, marker="o",
alpha=0.7, label="Cities")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

#Playing around with the time.strftime() function
plt.title("City Latitude vs Cloudiness (%s)" % time.strftime("%x"))
sns.set(style="whitegrid")
plt.savefig("../output_data/Cloudiness.png")

# %% [markdown]
# Cloud cover and geographical location have no relationship based on the "City Latitude vs Cloudiness" scatter plot above.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(clean_city_data_df['lat'], clean_city_data_df['wind_speed'], edgecolor="black", linewidths=1, marker="o",
alpha=1.0, label="Cities")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

#Playing around with the time.strftime() function
plt.title("City Latitude vs Wind Speed (mph) (%s)" % time.strftime("%x"))
sns.set(style="whitegrid")
plt.savefig("../output_data/WindSpeed.png")

# %% [markdown]
# Wind speeds and geographic location or proximity to the eaquator have no relationship based on the scatter plot shown above.

# %% [markdown]
# ## Linear Regression

# %%
#Create dataframes for the nother and southern hemispheres
north_df = clean_city_data_df.loc[pd.to_numeric(clean_city_data_df["lat"]).astype(float) > 0, :]
south_df = clean_city_data_df.loc[pd.to_numeric(clean_city_data_df["lat"]).astype(float) < 0, :]

# %%
#Review Northern DF = north_df
north_df
# Out:
#     country             city      lat       lon        date cloudiness  \
# 0        GL          qaanaaq  77.4840  -69.3632  1643577032        100
# 1        RU       nikolskoye  59.7035   30.7861  1643577032        100
# 3        US        menomonie  44.8755  -91.9193  1643577033        100
# 6        JP         ishigaki  24.3448  124.1572  1643577034         15
# 9        PT   ribeira grande  38.5167  -28.7000  1643577035         40
# ..      ...              ...      ...       ...         ...        ...
# 584      RU      deputatskiy  69.3000  139.9000  1643578020         82
# 586      NG           gashua  12.8710   11.0482  1643578020         18
# 587      US          wahiawa  21.5028 -158.0236  1643578020         75
# 588      GD    saint-georges  12.0564  -61.7485  1643578021         20
# 589      IN  firozpur jhirka  27.8000   76.9500  1643578021          0
#
#     humidity  max_temp  wind_speed
# 0         67     -7.91        6.64
# 1         95     27.39        6.73
# 3         63     26.65        3.44
# 6         63     63.14       27.56
# 9         63     59.40       20.71
# ..       ...       ...         ...
# 584       99    -25.06        2.71
# 586       14     64.99       10.38
# 587       61     75.87        9.22
# 588       74     82.08       14.97
# 589       44     53.47        1.92
#
# [401 rows x 9 columns]

# %%
#Review Southern DF = south_df
south_df
# Out:
#     country           city      lat       lon        date cloudiness humidity  \
# 2        ID       bengkulu  -3.8004  102.2655  1643577032        100       89
# 4        MV      hithadhoo  -0.6000   73.0833  1643576866         81       70
# 5        EC   puerto ayora  -0.7393  -90.3518  1643577033        100       73
# 7        MG       manakara -22.1333   48.0167  1643577034          9       81
# 8        AU    new norfolk -42.7826  147.0587  1643576945          5       75
# ..      ...            ...      ...       ...         ...        ...      ...
# 573      BR        chapeco -27.0964  -52.6183  1643577993         40       78
# 576      AU   port lincoln -34.7333  135.8667  1643577995         31       83
# 580      AU  coffs harbour -30.3000  153.1333  1643577996         40       93
# 582      BR        mazagao  -0.1150  -51.2894  1643578019         91       94
# 585      PG       lorengau  -2.0226  147.2712  1643577957        100       87
#
#      max_temp  wind_speed
# 2       75.97        3.27
# 4       81.61        9.04
# 5       85.96        8.84
# 7       72.64        1.07
# 8       58.87        1.97
# ..        ...         ...
# 573     80.13       11.50
# 576     66.54        8.16
# 580     75.47        8.05
# 582     78.85        5.06
# 585     78.30       12.01
#
# [189 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# using the Norhern Hemispher dataframe = north_df
#https://www.programcreek.com/python/example/84598/scipy.stats.linregress
#chart the Maximum Temp vs latitude using linear regression
x = pd.to_numeric(north_df['lat']).astype(float)
y = pd.to_numeric(north_df['max_temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress = x * slope + intercept

#define the line equation
#https://realpython.com/linear-regression-in-python/

#A linear regression line has an equation of the form Y = a + bX, 
#where X is the explanatory variable and Y is the dependent variable. 
#The slope of the line is b, and a is the intercept (the value of y when x = 0).

#http://www.stat.yale.edu/Courses/1997-98/101/linreg.htm

#linear regression is something with which I struggle or am challenged in Python and Pandas
#I googled and read several sites and posts.  I am just taking a leap that I am understanding it enough
#to put each of these pieces together.  I could have taken a more simple approach
#but I wanted to see if I could calc each component so that I could step through it
#and generate the actual equation for the slope and calc the r squared

line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot the data
plt.scatter(x,y)
plt.plot(x,regress, "r-")
plt.annotate(line_eq,(1,10),fontsize=15,color="purple")
plt.annotate(f"r squared ={rvalue}",(1,-10),fontsize=13,color="purple")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')

sns.set(style="whitegrid")

#Print the line equation and r squared
print(f"Regression line equation is: {line_eq}.")
print(f"r-squared equals: {rvalue}")

#Save the image
plt.savefig("../output_data/MaxTempvLinRegNH.png")
# Out:
# Regression line equation is: y =-1.31x + 90.2.
# r-squared equals: -0.84961761192042

# %% [markdown]
# NOTE: Observations appear AFTER the charts and graphs are generated for both Southern and Norther Hemispher for each topic or grouping.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#NOTE:For the Southern Henmisphere, I copied the code for the northern hemisphere and changed the data frame reference
#https://www.programcreek.com/python/example/84598/scipy.stats.linregress

# using the Southern Hemispher dataframe = south_df
#chart the Maximum Temp vs latitude using linear regression
x = pd.to_numeric(south_df['lat']).astype(float)
y = pd.to_numeric(south_df['max_temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress = x * slope + intercept

#define the line equation
#https://realpython.com/linear-regression-in-python/

#A linear regression line has an equation of the form Y = a + bX, 
#where X is the explanatory variable and Y is the dependent variable. 
#The slope of the line is b, and a is the intercept (the value of y when x = 0).

#http://www.stat.yale.edu/Courses/1997-98/101/linreg.htm

line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Print the line equation and r squared
print(f"Regression line equation is: {line_eq}.")
print(f"r-squared equals: {rvalue}")


#Plot the data
plt.scatter(x,y)
plt.plot(x,regress, "r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="orange")
plt.annotate(f"r squared ={rvalue}",(4,10),fontsize=13,color="orange")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')

sns.set(style="whitegrid")

#Save the image
plt.savefig("../output_data/MaxTempvLinRegSH.png")
# Out:
# Regression line equation is: y =0.21x + 78.88.
# r-squared equals: 0.3431575812189468

# %% [markdown]
# The above two charts comparing max temperatures for the northern and southern hemisphere shows a strong negative relationship
# between temperatures and distance relative to the equator.  The second chartt indicates a less strong postive relationsip in
# tempartures in relationship to the equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Same equation written earlier for the earlier regression analysis
#https://www.programcreek.com/python/example/84598/scipy.stats.linregress
#Just need to copy and paste the original code and change the y_val to reference Humidity in the north_df

# using the Norhern Hemispher dataframe = north_df
#chart the Maximum Temp vs latitude using linear regression
x = pd.to_numeric(north_df['lat']).astype(float)
y = pd.to_numeric(north_df['humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress= x * slope + intercept

#define the line equation

line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Print the line equation and r squared
print(f"Regression line equation is: {line_eq}.")
print(f"r-squared equals: {rvalue}")


#Plot the data
plt.scatter(x,y)
plt.plot(x,regress, "r-")
plt.annotate(line_eq,(40,15),fontsize=15,color="purple")
plt.annotate(f"r squared ={rvalue}",(40,25),fontsize=13,color="purple")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Northern Hemisphere - Humidity vs. Latitude Linear Regression')

sns.set(style="whitegrid")

#Save the image
plt.savefig("../output_data/HumTempLinRegNH.png")
# Out:
# Regression line equation is: y =0.5x + 48.81.
# r-squared equals: 0.4103964814534775

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#NOTE:For the remaining southern hemisphere line regression 
#https://www.programcreek.com/python/example/84598/scipy.stats.linregress
# using the Southern Hemispher dataframe = south_df
#chart the Humidity vs latitude using linear regression
x = pd.to_numeric(south_df['lat']).astype(float)
y = pd.to_numeric(south_df['humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress = x * slope + intercept

#define the line equation
#https://realpython.com/linear-regression-in-python/

#A linear regression line has an equation of the form Y = a + bX, 
#where X is the explanatory variable and Y is the dependent variable. 
#The slope of the line is b, and a is the intercept (the value of y when x = 0).

#http://www.stat.yale.edu/Courses/1997-98/101/linreg.htm

line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Print the line equation and r squared
print(f"Regression line equation is: {line_eq}.")
print(f"r-squared equals: {rvalue}")


#Plot the data
plt.scatter(x,y)
plt.plot(x,regress, "r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="orange")
plt.annotate(f"r squared ={rvalue}",(2,-10),fontsize=13,color="orange")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Southern Hemisphere - Humidity vs. Latitude Linear Regression')

sns.set(style="whitegrid")

#Save the image
plt.savefig("../output_data/HumidityvLinRegSH.png")
# Out:
# Regression line equation is: y =0.44x + 87.22.
# r-squared equals: 0.3304668244951972

# %% [markdown]
# Neither the northern or southern hemisphere have a strong correlation between humidity and proximity to the equator.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Same equation written earlier for the earlier regression analysis
#Just need to copy and paste the original code and change the y_val to reference cloudiness in the north_df

# using the Norhern Hemispher dataframe = north_df
#chart the cloudiness vs latitude using linear regression
x = pd.to_numeric(north_df['lat']).astype(float)
y = pd.to_numeric(north_df['cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress = x * slope + intercept

#define the line equation

line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Print the line equation and r squared
print(f"Regression line equation is: {line_eq}.")
print(f"r-squared equals: {rvalue}")


#Plot the data
plt.scatter(x,y)
plt.plot(x,regress, "r-")
plt.annotate(line_eq,(45,15),fontsize=15,color="purple")
plt.annotate(f"r squared ={rvalue}",(45,25),fontsize=13,color="purple")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Northern Hemisphere - Cloudiness vs. Latitude Linear Regression')

sns.set(style="whitegrid")

#Save the image
plt.savefig("../output_data/CloudinessLinRegNH.png")
# Out:
# Regression line equation is: y =0.58x + 31.04.
# r-squared equals: 0.283315318547379

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Same equation written earlier for the earlier regression analysis
#Just need to copy and paste the original code and change the y_val to reference cloudiness in the south_df

# using the Norhern Hemispher dataframe = north_df
#chart the cloudiness vs latitude using linear regression
x = pd.to_numeric(south_df['lat']).astype(float)
y = pd.to_numeric(south_df['cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress = x * slope + intercept

#define the line equation

line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Print the line equation and r squared
print(f"Regression line equation is: {line_eq}.")
print(f"r-squared equals: {rvalue}")


#Plot the data
plt.scatter(x,y)
plt.plot(x,regress, "r-")
plt.annotate(line_eq,(45,15),fontsize=15,color="purple")
plt.annotate(f"r squared ={rvalue}",(45,25),fontsize=13,color="purple")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Southern Hemisphere - Cloudiness vs. Latitude Linear Regression')

sns.set(style="whitegrid")

#Save the image
plt.savefig("../output_data/CloudinessLinRegSH.png")
# Out:
# Regression line equation is: y =0.99x + 84.97.
# r-squared equals: 0.35503075493618863

# %% [markdown]
# The line of best fit and the related scatter plots indicate that neither hemisphere has a strong correlation between the level of cloud cover and geographical proximity to the equator.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Same equation written earlier for the earlier regression analysis
#Just need to copy and paste the original code and change the y_val to reference wind speed in the north_df

# using the Norhern Hemispher dataframe = north_df
#chart the Wind Speed vs latitude using linear regression
x = pd.to_numeric(north_df['lat']).astype(float)
y = pd.to_numeric(north_df['wind_speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress = x * slope + intercept

#define the line equation

line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Print the line equation and r squared
print(f"Regression line equation is: {line_eq}.")
print(f"r-squared equals: {rvalue}")


#Plot the data
plt.scatter(x,y)
plt.plot(x,regress, "r-")
plt.annotate(line_eq,(20,30),fontsize=15,color="purple")
plt.annotate(f"r squared ={rvalue}",(20,35),fontsize=13,color="purple")
plt.xlabel('Latitude')
plt.ylabel('Windspeed')
plt.title('Northern Hemisphere - Wind Speed vs. Latitude Linear Regression')

sns.set(style="whitegrid")

#Save the image
plt.savefig("../output_data/WindSpeedLinRegNH.png")
# Out:
# Regression line equation is: y =0.04x + 6.62.
# r-squared equals: 0.12978443248599975

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Same equation written earlier for the earlier regression analysis
#Just need to copy and paste the original code and change the y_val to reference wind speed in the south_df

#https://www.programcreek.com/python/example/84598/scipy.stats.linregress

# using the Norhern Hemispher dataframe = north_df
#chart the Maximum Temp vs latitude using linear regression
x_val = pd.to_numeric(south_df['lat']).astype(float)
y_val = pd.to_numeric(south_df['wind_speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_val = x_val * slope + intercept

#define the line equation

line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Print the line equation and r squared
print(f"Regression line equation is: {line_eq}.")
print(f"r-squared equals: {rvalue}")


#Plot the data
plt.scatter(x_val,y_val)
plt.plot(x_val,regress_val, "r-")
plt.annotate(line_eq,(1,1),fontsize=15,color="purple")
plt.annotate(f"r squared ={rvalue}",(1,5),fontsize=13,color="purple")
plt.xlabel('Latitude')
plt.ylabel('Windspeed')
plt.title('Southern Hemisphere - Wind Speed vs. Latitude Linear Regression')

sns.set(style="whitegrid")

#Save the image
plt.savefig("../output_data/WindSpeedLinRegSH.png")
# Out:
# Regression line equation is: y =-0.11x + 5.82.
# r-squared equals: -0.2588782228167693

# %% [markdown]
# The line of best fit and the related scatter plots indicate that neither hemisphere has a strong correlation
# between the wind speed and geographical proximity to the equator.
