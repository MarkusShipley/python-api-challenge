# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import seaborn as sns

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#Use ! in front of the code if you are running terminal commands
#!pip install seaborn
#!pip freeze 
#!pip install citipy

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 596

# %%
#Just to check the cities in the list
print(cities)
# Out:
# ['busselton', 'grindavik', 'saryg-sep', 'taolanaro', 'vila velha', 'veraval', 'rikitea', 'kapaa', 'najran', 'hithadhoo', 'port elizabeth', 'killybegs', 'sorland', 'te anau', 'necochea', 'mar del plata', 'castro', 'hasaki', 'dolbeau', 'illoqqortoormiut', 'punta arenas', 'chaoyang', 'severo-kurilsk', 'atuona', 'saint-leu', 'albany', 'villa maria', 'inuvik', 'lolua', 'bambous virieux', 'pasighat', 'cape town', 'lucan', 'port augusta', 'thompson', 'qaanaaq', 'lompoc', 'taft', 'kavaratti', 'srandakan', 'narsaq', 'nouadhibou', 'hofn', 'ushuaia', 'paamiut', 'tougan', 'tezu', 'ballina', 'cidreira', 'tuktoyaktuk', 'elk city', 'portland', 'mataura', 'bethel', 'marcona', 'yellowknife', 'araouane', 'kaihua', 'hermanus', 'futog', 'maniitsoq', 'ilulissat', 'hobart', 'airai', 'comodoro rivadavia', 'puerto ayora', 'teahupoo', 'barentsburg', 'arlit', 'tsihombe', 'saskylakh', 'butaritari', 'caninde', 'roros', 'jamestown', 'sao filipe', 'santa maria', 'ponta delgada', 'bathsheba', 'bredasdorp', 'buala', 'yangambi', 'sarangani', 'saleaula', 'issa', 'faanui', 'iqaluit', 'soyo', 'karkaralinsk', 'izumo', 'nadym', 'tuatapere', 'lebu', 'kruisfontein', 'longyearbyen', 'edgewater', 'hovd', 'san ignacio', 'ribeira grande', 'sorong', 'broome', 'ostrovnoy', 'rungata', 'genhe', 'mahebourg', 'touba', 'clyde river', 'avarua', 'port alfred', 'torbay', 'malim', 'port hardy', 'tasiilaq', 'bluff', 'ranong', 'novoanninskiy', 'new norfolk', 'muli', 'viedma', 'shelburne', 'atar', 'morondava', 'phangnga', 'khatanga', 'charters towers', 'lorengau', 'erzin', 'puerto escondido', 'mabaruma', 'wapi pathum', 'east london', 'hilo', 'port shepstone', 'zhigansk', 'attawapiskat', 'nanortalik', 'sitka', 'salalah', 'malakal', 'solsvik', 'houma', 'lavrentiya', 'druzhba', 'vardo', 'saint george', 'ixtapa', 'sunzha', 'dauriya', 'jaragua', 'santa helena de goias', 'batemans bay', 'malwan', 'smithers', 'nikolskoye', 'luderitz', 'san carlos', 'tongling', 'vaitupu', 'porto novo', 'zacualpan', 'bacungan', 'adre', 'namibe', 'shchelyayur', 'grand river south east', 'belushya guba', 'tessalit', 'vaini', 'black river', 'barrow', 'hirara', 'winton', 'upernavik', 'saint-philippe', 'alofi', 'carnarvon', 'toliary', 'deputatskiy', 'norman wells', 'vestmanna', 'yumen', 'bang saphan', 'taoudenni', 'adrar', 'tukrah', 'touros', 'constitucion', 'codrington', 'balikpapan', 'husavik', 'bayir', 'dargaville', 'kirakira', 'roald', 'plettenberg bay', 'zlatoustovsk', 'totma', 'georgetown', 'aberdeen', 'dikson', 'mulchen', 'kavieng', 'sao caetano de odivelas', 'fort nelson', 'cabo san lucas', 'chuy', 'troitskoye', 'maun', 'chokurdakh', 'port blair', 'hinton', 'ocos', 'pisco', 'san patricio', 'kushima', 'nizhneyansk', 'lagoa', 'nkayi', 'talnakh', 'kadykchan', 'palabuhanratu', 'kodiak', 'sakhon nakhon', 'tikaitnagar', 'puerto ayacucho', 'dawlatabad', 'sinkat', 'satitoa', 'lac du bonnet', 'northam', 'dalvik', 'tevriz', 'kununurra', 'nacala', 'dalnerechensk', 'cherskiy', 'hammerfest', 'matagami', 'tabuk', 'pandan', 'hay river', 'broken hill', 'hailar', 'shirokaya rechka', 'caravelas', 'mezen', 'dolores', 'kijang', 'laguna', 'pevek', 'trairi', 'urumqi', 'auki', 'stamsund', 'verkhoyansk', 'kuche', 'belaya gora', 'yulara', 'gijon', 'nabire', 'tumannyy', 'ponta do sol', 'lixourion', 'ternate', 'kaitangata', 'lovozero', 'chicama', 'mettur', 'moen', 'shangrao', 'seydi', 'naspur', 'arraial do cabo', 'aykhal', 'snezhnogorsk', 'agudos', 'fortuna', 'yongan', 'mys shmidta', 'alice springs', 'nampula', 'tobermory', 'geraldton', 'bengkulu', 'wewak', 'sambava', 'vao', 'souillac', 'rolim de moura', 'rio gallegos', 'makakilo city', 'talaya', 'coquimbo', 'santa cruz', 'katsuura', 'ancud', 'port lincoln', 'walvis bay', 'cabedelo', 'kautokeino', 'zhanatas', 'labuhan', 'barmer', 'aleksandrovsk-sakhalinskiy', 'matamoros', 'komsomolskiy', 'port-gentil', 'novo aripuana', 'khasan', 'engenheiro beltrao', 'novichikha', 'omboue', 'nelson bay', 'bariri', 'magui', 'dzilam gonzalez', 'kargil', 'lasa', 'korampallam', 'augusto correa', 'dmitri ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).
#
# > **HINT:** The OpenWeatherMap API only allows 60 calls per minute under their free plan. Try using `time.sleep(60)` after each set of 50 cities to avoid API errors due to large calls.

# %%
#Openweather API Calls
url = "http://api.openweathermap.org/data/2.5/weather?"
#The open weather API requires units as a parameter
unit_parameter = "imperial"

# Build partial query URL and use sample city to test
query_url_test = f"{url}appid={weather_api_key}&units={unit_parameter}&q=Knoxville"
#Commented out the display (query_url) after testing because display revealed the keys in the url
#display (query_url_test)

# %%
#Partial QUery from Test Section Above
query_url= f"{url}appid={weather_api_key}&units={unit_parameter}&q="
#Commented out the display (query_url) after testing because display revealed the keys in the url
#display (query_url)

# %%
#Creating an empty dataframe
df = pd.DataFrame(columns=['country', 'city', 'lat', 'lon', 'date', 'cloudiness', 'humidity', 'max_temp', 'wind_speed'])

display(df)
# Out:
# Empty DataFrame
# Columns: [country, city, lat, lon, date, cloudiness, humidity, max_temp, wind_speed]
# Index: []

# %%
#Building the query
#I knew the query would would generate the correct results after the testing above using Knoxville.
query_url= f"{url}appid={weather_api_key}&units={unit_parameter}&q="

# %%
count = 1

for city in cities:
    if count % 50 == 0:
        time.sleep(60)
    try:
        print(f'Retrieving data for city {city}')
        #Get values for current city
        city_info = requests.get(query_url + city).json()
        country = city_info['sys']['country']
        date = city_info['dt']
        lat = city_info['coord']['lat']
        lon = city_info['coord']['lon']
        clouds = city_info['clouds']['all']
        humidity = city_info['main']['humidity']
        max_temp = city_info['main']['temp_max']
        wind_speed = city_info['wind']['speed']
        
        #Create a dictionary
        current_city_dict = {
            'country': country,
            'city': city,
            'lat': lat,
            'lon': lon,
            'date': date,
            'cloudiness': clouds,
            'humidity': humidity,
            'max_temp': max_temp,
            'wind_speed': wind_speed
        }
        
        #Convert dictionary to dataframe for current city
        current_city = pd.DataFrame([current_city_dict])
        
        #Concatenate main df with current city dataframe
        df = pd.concat([df, current_city]).reset_index(drop=True)
        
    except:
        print(f'Data for city {city} is not available')
    
    count+=1
# Out:
# Retrieving data for city busselton
# Retrieving data for city grindavik
# Retrieving data for city saryg-sep
# Retrieving data for city taolanaro
# Data for city taolanaro is not available
# Retrieving data for city vila velha
# Retrieving data for city veraval
# Retrieving data for city rikitea
# Retrieving data for city kapaa
# Retrieving data for city najran
# Retrieving data for city hithadhoo
# Retrieving data for city port elizabeth
# Retrieving data for city killybegs
# Retrieving data for city sorland
# Retrieving data for city te anau
# Retrieving data for city necochea
# Retrieving data for city mar del plata
# Retrieving data for city castro
# Retrieving data for city hasaki
# Retrieving data for city dolbeau
# Data for city dolbeau is not available
# Retrieving data for city illoqqortoormiut
# Data for city illoqqortoormiut is not available
# Retrieving data for city punta arenas
# Retrieving data for city chaoyang
# Retrieving data for city severo-kurilsk
# Retrieving data for city atuona
# Retrieving data for city saint-leu
# Retrieving data for city albany
# Retrieving data for city villa maria
# Retrieving data for city inuvik
# Retrieving data for city lolua
# Data for city lolua is not available
# Retrieving data for city bambous virieux
# Retrieving data for city pasighat
# Retrieving data for city cape town
# Retrieving data for city lucan
# Retrieving data for city port augusta
# Retrieving data for city thompson
# Retrieving data for city qaanaaq
# Retrieving data for city lompoc
# Retrieving data for city taft
# Retrieving data for city kavaratti
# Retrieving data for city srandakan
# Retrieving data for city narsaq
# Retrieving data for city nouadhibou
# Retrieving data for city hofn
# Retrieving data for city ushuaia
# Retrieving data for city paamiut
# Retrieving data for city tougan
# Retrieving data for city tezu
# Retrieving data for city ballina
# Retrieving data for city cidreira
# Retrieving data for city tuktoyaktuk
# Retrieving data for city elk city
# Retrieving data for city portland
# Retrieving data for city mataura
# Retrieving data for city bethel
# Retrieving data for city marcona
# Data for city marcona is not available
# Retrieving data for city yellowknife
# Retrieving data for city araouane
# Retrieving data for city kaihua
# Retrieving data for city hermanus
# Retrieving data for city futog
# Retrieving data for city maniitsoq
# Retrieving data for city ilulissat
# Retrieving data for city hobart
# Retrieving data for city airai
# Retrieving data for city comodoro rivadavia
# Retrieving data for city puerto ayora
# Retrieving data for city teahupoo
# Retrieving data for city barentsburg
# Data for city barentsburg is not available
# Retrieving data for city arlit
# Retrieving data for city tsihombe
# Data for city tsihombe is not available
# Retrieving data for city saskylakh
# Retrieving data for city butaritari
# Retrieving data for city caninde
# Retrieving data for city roros
# Retrieving data for city jamestown
# Retrieving data for city sao filipe
# Retrieving data for city santa maria
# Retrieving data for city ponta delgada
# Retrieving data for city bathsheba
# Retrieving data for city bredasdorp
# Retrieving data for city buala
# Retrieving data for city yangambi
# Retrieving data for city sarangani
# Retrieving data for city saleaula
# Data for city saleaula is not available
# Retrieving data for city issa
# Retrieving data for city faanui
# Retrieving data for city iqaluit
# Retrieving data for city soyo
# Retrieving data for city karkaralinsk
# Data for city karkaralinsk is not available
# Retrieving data for city izumo
# Retrieving data for city nadym
# Retrieving data for city tuatapere
# Retrieving data for city lebu
# Retrieving data for city kruisfontein
# Retrieving data for city longyearbyen
# Retrieving data for city edgewater
# Retrieving data for city hovd
# Retrieving data for city san ignacio
# Retrieving data for city ribeira grande
# Retrieving data for city sorong
# Retrieving data for city broome
# Retrieving data for city ostrovnoy
# Retrieving data for city rungata
# Data for city rungata is not available
# Retrieving data for city genhe
# Retrieving data for city mahebourg
# Retrieving data for city touba
# Retrieving data for city clyde river
# Retrieving data for city avarua
# Retrieving data for city port alfred
# Retrieving data for city torbay
# Retrieving data for city malim
# Retrieving data for city port hardy
# Retrieving data for city tasiilaq
# Retrieving data for city bluff
# Retrieving data for city ranong
# Retrieving data for city novoanninskiy
# Retrieving data for city new norfolk
# Retrieving data for city muli
# Retrieving data for city viedma
# Retrieving data for city shelburne
# Retrieving data for city atar
# Retrieving data for city morondava
# Retrieving data for city phangnga
# Retrieving data for city khatanga
# Retrieving data for city charters towers
# Retrieving data for city lorengau
# Retrieving data for city erzin
# Retrieving data for city puerto escondido
# Retrieving data for city mabaruma
# Retrieving data for city wapi pathum
# Retrieving data for city east london
# Retrieving data for city hilo
# Retrieving data for city port shepstone
# Retrieving data for city zhigansk
# Retrieving data for city attawapiskat
# Data for city attawapiskat is not available
# Retrieving data for city nanortalik
# Retrieving data for city sitka
# Retrieving data for city salalah
# Retrieving data for city malakal
# Retrieving data for city solsvik
# Data for city solsvik is not available
# Retrieving data for city houma
# Retrieving data for city lavrentiya
# Retrieving data for city druzhba
# Retrieving data for city vardo
# Retrieving data for city saint george
# Retrieving data for city ixtapa
# Retrieving data for city sunzha
# Retrieving data for city dauriya
# Retrieving data for city jaragua
# Retrieving data for city santa helena de goias
# Retrieving data for city batemans bay
# Retrieving data for city malwan
# Data for city malwan is not available
# Retrieving data for city smithers
# Retrieving data for city nikolskoye
# Retrieving data for city luderitz
# Retrieving data for city san carlos
# Retrieving data for city tongling
# Retrieving data for city vaitupu
# Data for city vaitupu is not available
# Retrieving data for city porto novo
# Retrieving data for city zacualpan
# Retrieving data for city bacungan
# Retrieving data for city adre
# Retrieving data for city namibe
# Retrieving data for city shchelyayur
# Data for city shchelyayur is not available
# Retrieving data for city grand river south east
# Data for city grand river south east is not available
# Retrieving data for city belushya guba
# Data for city belushya guba is not available
# Retrieving data for city tessalit
# Retrieving data for city vaini
# Retrieving data for city black river
# Retrieving data for city barrow
# Retrieving data for city hirara
# Retrieving data for city winton
# Retrieving data for city upernavik
# Retrieving data for city saint-philippe
# Retrieving data for city alofi
# Retrieving data for city carnarvon
# Retrieving data for city toliary
# Data for city toliary is not available
# Retrieving data for city deputatskiy
# Retrieving data for city norman wells
# Retrieving data for city vestmanna
# Retrieving data for city yumen
# Retrieving data for city bang saphan
# Retrieving data for city taoudenni
# Retrieving data for city adrar
# Retrieving data for city tukrah
# Retrieving data for city touros
# Retrieving data for city constitucion
# Retrieving data for city codrington
# Retrieving data for city balikpapan
# Retrieving data for city husavik
# Retrieving data for city bayir
# Retrieving data for city dargaville
# Retrieving data for city kirakira
# Retrieving data for city roald
# Retrieving data for city plettenberg bay
# Retrieving data for city zlatoustovsk
# Data for city zlatoustovsk is not available
# Retrieving data for city totma
# Retrieving data for city georgetown
# Retrieving data for city aberdeen
# Retrieving data for city dikson
# Retrieving data for city mulchen
# Retrieving data for city kavieng
# Retrieving data for city sao caetano de odivelas
# Retrieving data for city fort nelson
# Retrieving data for city cabo san lucas
# Retrieving data for city chuy
# Retrieving data for city troitskoye
# Retrieving data for city maun
# Retrieving data for city chokurdakh
# Retrieving data for city port blair
# Retrieving data for city hinton
# Retrieving data for city ocos
# Retrieving data for city pisco
# Retrieving data for city san patricio
# Retrieving data for city kushima
# Retrieving data for city nizhneyansk
# Data for city nizhneyansk is not available
# Retrieving data for city lagoa
# Retrieving data for city nkayi
# Retrieving data for city talnakh
# Retrieving data for city kadykchan
# Data for city kadykchan is not available
# Retrieving data for city palabuhanratu
# Data for city palabuhanratu is not available
# Retrieving data for city kodiak
# Retrieving data for city sakhon nakhon
# Retrieving data for city tikaitnagar
# Retrieving data for city puerto ayacucho
# Retrieving data for city dawlatabad
# Retrieving data for city sinkat
# Data for city sinkat is not available
# Retrieving data for city satitoa
# Data for city satitoa is not available
# Retrieving data for city lac du bonnet
# Retrieving data for city northam
# Retrieving data for city dalvik
# Retrieving data for city tevriz
# Retrieving data for city kununurra
# Retrieving data for city nacala
# Retrieving data for city dalnerechensk
# Retrieving data for city cherskiy
# Retrieving data for city hammerfest
# Retrieving data for city matagami
# Retrieving data for city tabuk
# Retrieving data for city pandan
# Retrieving data for city hay river
# Retrieving data for city broken hill
# Retrieving data for city hailar
# Retrieving data for city shirokaya rechka
# Retrieving data for city caravelas
# Retrieving data for city mezen
# Retrieving data for city dolores
# Retrieving data for city kijang
# Retrieving data for city laguna
# Retrieving data for city pevek
# Retrieving data for city trairi
# Retrieving data for city urumqi
# Retrieving data for city auki
# Retrieving data for city stamsund
# Data for city stamsund is not available
# Retrieving data for city verkhoyansk
# Retrieving data for city kuche
# Data for city kuche is not available
# Retrieving data for city belaya gora
# Retrieving data for city yulara
# Retrieving data for city gijon
# Retrieving data for city nabire
# Retrieving data for city tumannyy
# Data for city tumannyy is not available
# Retrieving data for city ponta do sol
# Retrieving data for city lixourion
# Retrieving data for city ternate
# Retrieving data for city kaitangata
# Retrieving data for city lovozero
# Retrieving data for city chicama
# Retrieving data for city mettur
# Retrieving data for city moen
# Retrieving data for city shangrao
# Retrieving data for city seydi
# Retrieving data for city naspur
# Retrieving data for city arraial do cabo
# Retrieving data for city aykhal
# Retrieving data for city snezhnogorsk
# Retrieving data for city agudos
# Retrieving data for city fortuna
# Retrieving data for city yongan
# Retrieving data for city mys shmidta
# Data for city mys shmidta is not available
# Retrieving data for city alice springs
# Retrieving data for city nampula
# Retrieving data for city tobermory
# Retrieving data for city geraldton
# Retrieving data for city bengkulu
# Retrieving data for city wewak
# Retrieving data for city sambava
# Retrieving data for city vao
# Retrieving data for city souillac
# Retrieving data for city rolim de moura
# Data for city rolim de moura is not available
# Retrieving data for city rio gallegos
# Retrieving data for city makakilo city
# Retrieving data for city talaya
# Retrieving data for city coquimbo
# Retrieving data for city santa cruz
# Retrieving data for city katsuura
# Retrieving data for city ancud
# Retrieving data for city port lincoln
# Retrieving data for city walvis bay
# Retrieving data for city cabedelo
# Retrieving data for city kautokeino
# Retrieving data for city zhanatas
# Data for city zhanatas is not available
# Retrieving data for city labuhan
# Retrieving data for city barmer
# Retrieving data for city aleksandrovsk-sakhalinskiy
# Retrieving data for city matamoros
# Retrieving data for city komsomolskiy
# Retrieving data for city port-gentil
# Retrieving data for city novo aripuana
# Retrieving data for city khasan
# Retrieving data for city engenheiro beltrao
# Retrieving data for city novichikha
# Retrieving data for city omboue
# Retrieving data for city nelson bay
# Retrieving data for city bariri
# Retrieving data for city magui
# Data for city magui is not available
# Retrieving data for city dzilam gonzalez
# Retrieving data for city kargil
# Retrieving data for city lasa
# Retrieving data for city korampallam
# Retrieving data for city augusto correa
# Retrieving data for city dmitriyevskoye
# Retrieving data for city victoria
# Retrieving data for city asau
# Retrieving data for city kingori
# Retrieving data for city chernyshevskiy
# Retrieving data for city maragogi
# Retrieving data for city bitung
# Retrieving data for city keti bandar
# Retrieving data for city bolungarvik
# Data for city bolungarvik is not available
# Retrieving data for city samusu
# Data for city samusu is not available
# Retrieving data for city saint-francois
# Retrieving data for city takoradi
# Retrieving data for city meadow lake
# Retrieving data for city galesong
# Retrieving data for city bilma
# Retrieving data for city cayenne
# Retrieving data for city almeirim
# Retrieving data for city ketchenery
# Data for city ketchenery is not available
# Retrieving data for city manggar
# Retrieving data for city grand centre
# Data for city grand centre is not available
# Retrieving data for city tommot
# Retrieving data for city sioux lookout
# Retrieving data for city tarrafal
# Retrieving data for city mandalgovi
# Retrieving data for city provideniya
# Retrieving data for city rawson
# Retrieving data for city akureyri
# Retrieving data for city litovko
# Retrieving data for city muhoroni
# Retrieving data for city baykit
# Retrieving data for city quatre cocos
# Retrieving data for city savonlinna
# Retrieving data for city kieta
# Retrieving data for city howard springs
# Retrieving data for city san javier
# Retrieving data for city cockburn town
# Retrieving data for city ruidoso
# Retrieving data for city chapais
# Retrieving data for city korla
# Retrieving data for city tres arroyos
# Retrieving data for city srednekolymsk
# Retrieving data for city karpathos
# Retrieving data for city talas
# Retrieving data for city la ronge
# Retrieving data for city tevaitoa
# Retrieving data for city pangnirtung
# Retrieving data for city sentyabrskiy
# Data for city sentyabrskiy is not available
# Retrieving data for city banda aceh
# Retrieving data for city panama city
# Retrieving data for city mahon
# Retrieving data for city fairbanks
# Retrieving data for city martin
# Retrieving data for city mount gambier
# Retrieving data for city nyurba
# Retrieving data for city hastings
# Retrieving data for city bodden town
# Retrieving data for city ugoofaaru
# Retrieving data for city kidal
# Retrieving data for city flin flon
# Retrieving data for city rudbar
# Retrieving data for city campoverde
# Retrieving data for city celestun
# Retrieving data for city iberia
# Retrieving data for city hambantota
# Retrieving data for city saldanha
# Retrieving data for city barao de melgaco
# Retrieving data for city montague
# Retrieving data for city samalaeulu
# Data for city samalaeulu is not available
# Retrieving data for city cairns
# Retrieving data for city bridlington
# Retrieving data for city neyshabur
# Retrieving data for city tawau
# Retrieving data for city katherine
# Retrieving data for city kodinsk
# Retrieving data for city mollendo
# Retrieving data for city felidhoo
# Data for city felidhoo is not available
# Retrieving data for city castleblayney
# Retrieving data for city inirida
# Retrieving data for city blagoyevo
# Retrieving data for city gwadar
# Retrieving data for city januaria
# Retrieving data for city kapit
# Retrieving data for city dukat
# Retrieving data for city viligili
# Data for city viligili is not available
# Retrieving data for city hervey bay
# Retrieving data for city cap malheureux
# Retrieving data for city asuncion
# Retrieving data for city olinda
# Retrieving data for city deming
# Retrieving data for city canar
# Retrieving data for city poum
# Retrieving data for city egvekinot
# Retrieving data for city kalemie
# Retrieving data for city aklavik
# Retrieving data for city amderma
# Data for city amderma is not available
# Retrieving data for city grants pass
# Retrieving data for city kiunga
# Retrieving data for city folldal
# Retrieving data for city vallenar
# Retrieving data for city kahului
# Retrieving data for city kudat
# Retrieving data for city mount isa
# Retrieving data for city bam
# Retrieving data for city aasiaat
# Retrieving data for city grand gaube
# Retrieving data for city liepaja
# Retrieving data for city waipawa
# Retrieving data for city shimoda
# Retrieving data for city ayagoz
# Retrieving data for city paradwip
# Data for city paradwip is not available
# Retrieving data for city pechora
# Retrieving data for city madimba
# Retrieving data for city port hueneme
# Retrieving data for city hayden
# Retrieving data for city nazareno
# Retrieving data for city llangefni
# Retrieving data for city pietarsaari
# Retrieving data for city bull savanna
# Retrieving data for city esperance
# Retrieving data for city upington
# Retrieving data for city shenjiamen
# Retrieving data for city sao joaquim
# Retrieving data for city arawa
# Retrieving data for city san jeronimo
# Retrieving data for city tsiroanomandidy
# Retrieving data for city ust-charyshskaya pristan
# Retrieving data for city coihaique
# Retrieving data for city general roca
# Retrieving data for city andenes
# Retrieving data for city san luis
# Retrieving data for city barreirinha
# Retrieving data for city eyl
# Retrieving data for city toora-khem
# Retrieving data for city jomalig
# Data for city jomalig is not available
# Retrieving data for city torrington
# Retrieving data for city sangmelima
# Retrieving data for city athabasca
# Retrieving data for city henties bay
# Retrieving data for city hukuntsi
# Retrieving data for city pozo colorado
# Retrieving data for city moville
# Retrieving data for city lahaina
# Retrieving data for city beloha
# Retrieving data for city wonthaggi
# Retrieving data for city poopo
# Retrieving data for city mangrol
# Retrieving data for city gurupi
# Retrieving data for city urdzhar
# Data for city urdzhar is not available
# Retrieving data for city issoudun
# Retrieving data for city manokwari
# Retrieving data for city arman
# Retrieving data for city san-pedro
# Retrieving data for city manzhouli
# Retrieving data for city konosha
# Retrieving data for city kimbe
# Retrieving data for city guanica
# Retrieving data for city kumluca
# Retrieving data for city villarrobledo
# Retrieving data for city weligama
# Retrieving data for city oranjemund
# Retrieving data for city lambarene
# Retrieving data for city mahaicony
# Data for city mahaicony is not available
# Retrieving data for city warqla
# Data for city warqla is not available
# Retrieving data for city alta floresta
# Retrieving data for city noshiro
# Retrieving data for city richards bay
# Retrieving data for city yankton
# Retrieving data for city sivaki
# Retrieving data for city vestmannaeyjar
# Retrieving data for city balkanabat
# Retrieving data for city kiruna
# Retrieving data for city laramie
# Retrieving data for city caetite
# Retrieving data for city vanavara
# Retrieving data for city jafarpur
# Retrieving data for city emerald
# Retrieving data for city rupert
# Retrieving data for city haines junction
# Retrieving data for city dutlwe
# Retrieving data for city churapcha
# Retrieving data for city lengshuitan
# Retrieving data for city kaeo
# Retrieving data for city derzhavinsk
# Retrieving data for city trinidad
# Retrieving data for city slave lake
# Retrieving data for city skalistyy
# Data for city skalistyy is not available
# Retrieving data for city wabana
# Retrieving data for city diapaga
# Retrieving data for city tiksi
# Retrieving data for city mrirt
# Data for city mrirt is not available
# Retrieving data for city nipawin
# Retrieving data for city solnechnyy
# Retrieving data for city mitsamiouli
# Retrieving data for city skegness
# Retrieving data for city san policarpo
# Retrieving data for city karaul
# Data for city karaul is not available
# Retrieving data for city amboasary
# Retrieving data for city manoel urbano
# Retrieving data for city kloulklubed
# Retrieving data for city durgapur
# Retrieving data for city flinders
# Retrieving data for city prince rupert
# Retrieving data for city bani
# Retrieving data for city radviliskis
# Retrieving data for city katsiveli
# Data for city katsiveli is not available
# Retrieving data for city santa isabel do rio negro
# Retrieving data for city moerai
# Retrieving data for city mamallapuram
# Retrieving data for city verkhnyaya inta
# Retrieving data for city meyungs
# Data for city meyungs is not available
# Retrieving data for city darlawn
# Retrieving data for city znamenskoye
# Retrieving data for city wahran
# Data for city wahran is not available
# Retrieving data for city yaan
# Retrieving data for city alappuzha
# Retrieving data for city hami
# Retrieving data for city berlevag
# Retrieving data for city julio de castilhos
# Retrieving data for city byron bay
# Retrieving data for city chumikan
# Retrieving data for city pag
# Retrieving data for city vaitape
# Retrieving data for city bandarbeyla
# Retrieving data for city palu
# Retrieving data for city lawrence
# Retrieving data for city pundaguitan
# Retrieving data for city samana
# Retrieving data for city abu samrah
# Retrieving data for city olafsvik
# Retrieving data for city klaksvik
# Retrieving data for city ust-nera
# Retrieving data for city urengoy
# Retrieving data for city qingyuan
# Retrieving data for city xining
# Retrieving data for city vakhrushevo
# Retrieving data for city ondorhaan
# Data for city ondorhaan is not available
# Retrieving data for city magadan
# Retrieving data for city carauari
# Retrieving data for city kawalu
# Retrieving data for city barbatesti
# Retrieving data for city umzimvubu
# Data for city umzimvubu is not available
# Retrieving data for city caluquembe
# Retrieving data for city yicheng
# Retrieving data for city havre-saint-pierre
# Retrieving data for city williams lake
# Retrieving data for city katangli
# Retrieving data for city sovetsk
# Retrieving data for city ust-maya
# Retrieving data for city leo
# Retrieving data for city jasper
# Retrieving data for city concarneau
# Retrieving data for city utiroa
# Data for city utiroa is not available
# Retrieving data for city kamaishi
# Retrieving data for city tilichiki
# Retrieving data for city sinnamary
# Retrieving data for city holme
# Retrieving data for city zaoyang
# Retrieving data for city zeya
# Retrieving data for city lata
# Retrieving data for city kuala terengganu
# Retrieving data for city honningsvag
# Retrieving data for city zhanakorgan
# Retrieving data for city finote selam
# Retrieving data for city erenhot
# Retrieving data for city dingle
# Retrieving data for city antalaha
# Retrieving data for city barbar
# Data for city barbar is not available
# Retrieving data for city catuday
# Retrieving data for city bargal
# Data for city bargal is not available
# Retrieving data for city tambura
# Retrieving data for city havelock
# Retrieving data for city gao
# Retrieving data for city jijiga
# Retrieving data for city kuusamo
# Retrieving data for city hearst
# Retrieving data for city ketchikan

# %%
display(df)
# Out:
#     country        city      lat       lon        date cloudiness humidity  \
# 0        AU   busselton -33.6500  115.3333  1643325133          0       75
# 1        IS   grindavik  63.8424  -22.4338  1643325134        100       93
# 2        RU   saryg-sep  51.5000   95.6000  1643325134        100       99
# 3        BR  vila velha -20.3297  -40.2925  1643325134          0       86
# 4        IN     veraval  20.9000   70.3667  1643325135          0       37
# ..      ...         ...      ...       ...         ...        ...      ...
# 535      ML         gao  16.6362    1.6370  1643325972          7       20
# 536      ET      jijiga   9.3500   42.8000  1643325973         70       39
# 537      FI     kuusamo  65.9667   29.1833  1643325973        100       92
# 538      CA      hearst  49.6835  -83.6665  1643325973        100       90
# 539      US   ketchikan  55.3422 -131.6461  1643325974         75       75
#
#      max_temp  wind_speed
# 0       60.04       10.42
# 1       39.67       23.02
# 2       -8.27        0.85
# 3       78.94        1.01
# 4       63.07       15.52
# ..        ...         ...
# 535     62.80       13.04
# 536     56.89       10.45
# 537     15.84        2.30
# 538     -7.35        9.71
# 539     43.27       16.11
#
# [540 rows x 9 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#The solution approach I used moved variables into a dictionary and the dictionary into a pandaframe at each city iteration
#The concat option was used to stack the dataframes after the each cities dataframe from populated.

# %%
#Export df Dataframe with cities data to the output_data folder
df.to_csv('../output_data/cities_output.csv')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_df = df[df['humidity'] > 100] 
    
print('\nResult dataframe :\n', weather_df)

#Based on the results below, none of my cities in the df (now weather_df) have humidity greater than 100.
# Out:
# Result dataframe :
#  Empty DataFrame
# Columns: [country, city, lat, lon, date, cloudiness, humidity, max_temp, wind_speed]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
#Not applicable because none of my city data has humidity greater than 100 or 100%

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

#ASK TUTOR ABOUT 'inplace = false'

#Per instructions, going to make the clean_city_data into the data frame I am using

clean_city_data_df = df

display(clean_city_data_df)
# Out:
#     country        city      lat       lon        date cloudiness humidity  \
# 0        AU   busselton -33.6500  115.3333  1643325133          0       75
# 1        IS   grindavik  63.8424  -22.4338  1643325134        100       93
# 2        RU   saryg-sep  51.5000   95.6000  1643325134        100       99
# 3        BR  vila velha -20.3297  -40.2925  1643325134          0       86
# 4        IN     veraval  20.9000   70.3667  1643325135          0       37
# ..      ...         ...      ...       ...         ...        ...      ...
# 535      ML         gao  16.6362    1.6370  1643325972          7       20
# 536      ET      jijiga   9.3500   42.8000  1643325973         70       39
# 537      FI     kuusamo  65.9667   29.1833  1643325973        100       92
# 538      CA      hearst  49.6835  -83.6665  1643325973        100       90
# 539      US   ketchikan  55.3422 -131.6461  1643325974         75       75
#
#      max_temp  wind_speed
# 0       60.04       10.42
# 1       39.67       23.02
# 2       -8.27        0.85
# 3       78.94        1.01
# 4       63.07       15.52
# ..        ...         ...
# 535     62.80       13.04
# 536     56.89       10.45
# 537     15.84        2.30
# 538     -7.35        9.71
# 539     43.27       16.11
#
# [540 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#temp vs latitude scatterplot, format time
plt.scatter(clean_city_data_df["lat"],
            clean_city_data_df["max_temp"],
 edgecolor="black", linewidths=1, marker="o",
 alpha=0.8, label="Cities")
# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
#sns is a seaborn reference - saw a youtube video and few posts about using seaborn
#Just testing it out
sns.set()
# Save the figure
plt.savefig("Latitude vs Temperature (F).png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
